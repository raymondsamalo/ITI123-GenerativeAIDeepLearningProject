# %% [markdown]
# # yolo-preprocessed

# %%
# %%capture
# !pip install ultralytics wandb torch yaml scikit-learn seaborn tqdm matplotlib cv2

# %%
import sys
sys.path.append('.')
# from yolo import ODIRYOLOTrainer
from yolo_trainer import ODIRYOLOTrainer

# %%
run_name = "yolo11n-cls-preprocessed"
model_version = 'yolo11n-cls'
data_dir = "./ODIR-2019/YOLO/preprocessed"
project_name = "odir-2019-yolo"

# %% [markdown]
# ## Train

# %%
import wandb

wandb.init(project=project_name, name=run_name)
trainer = ODIRYOLOTrainer(model_version=model_version, run_name=run_name, use_wandb=True,wandb_run=wandb.run)
trainer.train_from_folder(data_folder=data_dir, epochs=100, batch_size=-1, imgsz=512, patience=30)
# Out:
# wandb: Currently logged in as: raymond-samalo (samalo) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260203_113310-jszswl2o</code>
# Syncing run <strong><a href='https://wandb.ai/samalo/odir-2019-yolo/runs/jszswl2o' target="_blank">yolo11n-cls-preprocessed</a></strong> to <a href='https://wandb.ai/samalo/odir-2019-yolo' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/samalo/odir-2019-yolo' target="_blank">https://wandb.ai/samalo/odir-2019-yolo</a>
#  View run at <a href='https://wandb.ai/samalo/odir-2019-yolo/runs/jszswl2o' target="_blank">https://wandb.ai/samalo/odir-2019-yolo/runs/jszswl2o</a>
# ---------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Validate

# %%
trainer.evaluate_on_validation_set(data_folder=data_dir, batch_size=32, imgsz=512)

# %% [markdown]
# ## Test

# %%
trainer.evaluate_on_test_set(data_folder=data_dir, batch_size=32, imgsz=512)

# %% [markdown]
# ## Save

# %%
# 4. Save trained model
trainer.save_model(
    save_dir='./ODIR-2019/results',
    model_name=run_name,
    save_format='pt'
)
