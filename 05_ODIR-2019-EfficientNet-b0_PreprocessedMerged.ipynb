# %% [markdown]
# # EfficientNet-B0 Preprocessed Merged
#
# Here we run experiment with ODIR-2019 Preprocessed images and additional training images from Ocular Diseases DataSet
# except for Normal which we leave the ODIR-2019 original images as it is

# %%
# %%capture
# !pip install efficientnet-pytorch wandb torch torchvision scikit-learn seaborn tqdm

# %%
import sys
sys.path.append('.')

from efficient_net import EfficientNetTrainer

# %%
from util import get_train_device

device_for_training = get_train_device()
# Out:
# Using NVIDIA GPU (CUDA)

# %% [markdown]
# We use EfficientNet-B0 as we want to target edge device

# %%
import wandb
config = {
    'data_dir': './ODIR-2019/YOLO/preprocessed_merged',  # Your dataset path
    'model_name': 'efficientnet-b0',
    'num_classes': 8,
    'image_size': 512,
    'batch_size': 16,  # Smaller for Jupyter
    'epochs': 30,
    'lr': 0.001,
    'weight_decay': 1e-4,
    'optimizer': 'adamw',
    'scheduler': 'cosine',
    'fine_tune': True,
    'unfreeze_blocks': 3,
    'label_smoothing': 0.1,
    'num_workers': 2,  # Lower for Jupyter
    'use_amp': True,
    'seed': 42
}
wandb.init(project="odir-2019", name="efficientnet-b0_preprocessed_merged", config=config)
trainer = EfficientNetTrainer(config)
trainer.train()
# Out:
# wandb: Currently logged in as: raymond-samalo (samalo) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260205_160717-fs9afqwx</code>
# Syncing run <strong><a href='https://wandb.ai/samalo/odir-2019/runs/fs9afqwx' target="_blank">efficientnet-b0_preprocessed_merged</a></strong> to <a href='https://wandb.ai/samalo/odir-2019' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/samalo/odir-2019' target="_blank">https://wandb.ai/samalo/odir-2019</a>
#  View run at <a href='https://wandb.ai/samalo/odir-2019/runs/fs9afqwx' target="_blank">https://wandb.ai/samalo/odir-2019/runs/fs9afqwx</a>
# Using device: cuda
# Loading efficientnet-b0 with 8 classes...
# Loaded pretrained weights for efficientnet-b0
# ...

# %%
# cell 6: Test
test_loss, test_acc, test_f1 = trainer.test()
print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}, Test F1: {test_f1:.4f}")
# Out:
# ...
# Testing Model
# ...
# Model loaded from /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260205_160717-fs9afqwx/files/best_model.pth
# Testing: 100%|██████████| 40/40 [00:11<00:00,  3.44it/s, Loss=1.1922, Acc=65.23%]
# 📊 Test Results:
# Test Loss: 1.1922
# Test Accuracy: 65.23%
# Test Weighted F1 Score: 0.6405
# Average Inference Time per Image: 5.45 ms
#
# 📋 Detailed Classification Report:
#               precision    recall  f1-score   support
#
#       normal       0.66      0.79      0.72       282
#     diabetes       0.60      0.53      0.56       160
#     glaucoma       0.71      0.43      0.53        28
#     cataract       0.82      0.85      0.84        27
#       ageing       0.59      0.62      0.60        26
# hypertension       0.00      0.00      0.00        13
#       myopia       0.86      0.83      0.84        23
#        other       0.59      0.47      0.52        68
#
#     accuracy                           0.65       627
# ...

# %%
import os
final_model_path = os.path.join('ODIR-2019/results/', 'efficientnet-b0_preprocessed.pth')
trainer.save_model(final_model_path)
# Out:
# Model saved to ODIR-2019/results/efficientnet-b0_preprocessed.pth

# %%
wandb.finish()
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>learning_rate</td><td>█████▇▇▇▇▆▆▆▅▅▅▄▄▃▃▃▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>test_acc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>train_acc</td><td>▁▄▄▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇█████████</td></tr><tr><td>train_f1</td><td>▁▃▄▅▅▆▆▆▆▇▆▇▇▇▇▇▇▇▇▇▇█████████</td></tr><tr><td>train_loss</td><td>█▅▅▄▄▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▂▃▄▅▅▅▅
# ...
