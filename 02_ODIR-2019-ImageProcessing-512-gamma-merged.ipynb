# %% [markdown]
# # Processing Images For Merged Dataset
#
# Here we enhance the images (training and testing) to improve the image quality.
#
# The processing steps:
# 1. Reads the input image
# 2. Converts from BGR to RGB
# 3. Crop black border around retina:
#     - ODIR images have large black margins → waste resolution.
# 4. Center the retina
#     - More consistent images
# 5. Mask outside retina :
#     - Removes corner glare
#     - Removes camera borders
#     - Keeps retinal signal intact
# 6. Gamma correction to 0.9
# 7. Saves the processed
#
# ```python
#     def preprocess_image(self, img):
#         img = self.crop_black_border(img)
#         img = self.center_retina(img)
#         img = self.mask_outside_retina(img)
#         img = self.gamma_correction(img)
#         return img
# ```

# %% [markdown]
# Define display images function

# %%
import os
import cv2
from matplotlib import pyplot as plt
def display_images(image_filenames:list[str], title="Image DataSet", col_count = 10):
    plt.suptitle(title, fontsize=20)
    img_count = len(image_filenames)
    plt.figure(figsize=(15, 15))
    for i in range(1, img_count+1):
        plt.subplot(5, col_count, i)
        image_path=image_filenames[i-1]
        image_name=os.path.basename(image_path)
        img = cv2.imread(image_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        plt.imshow(img, aspect="auto")
        plt.title(f"{image_name}")
        plt.axis(False)
    plt.show();

# %% [markdown]
# Define our image processor class

# %%
import cv2
import numpy as np
from pathlib import Path

class ODIRImageProcessor:
    """Simple processor for ODIR retinal images"""
    
    def __init__(self, output_size=512):
        self.output_size = output_size
    
    def process(self, input_path, output_path=None, skip_if_exist=True, gamma=0.9, threshold=10):
        """
        Process a single ODIR image
        
        Args:
            input_path: Path to input image
            output_path: Optional path to save result. If None, returns image array
        
        Returns:
            Processed image as numpy array
        """
        if skip_if_exist and output_path is not None:
            if os.path.exists(output_path):
                print(f"Skip as processed image existed: {output_path}")
                return

        # Read image
        img = cv2.imread(str(input_path))
        if img is None:
            raise ValueError(f"Cannot read image: {input_path}")
        
        # Convert BGR to RGB
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        
        # Call Preprocess script
        img = self.preprocess_image(img,threshold=threshold,gamma=gamma)

        # Convert back to BGR for saving/display
        img_bgr = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        
        # Save if output path is provided
        if output_path:
            cv2.imwrite(str(output_path), img_bgr)
            print(f"Saved processed image to: {output_path}")
        
       # return img_bgr
    def preprocess_image(self, img, threshold=10, gamma=0.9):
        img = self.resize(img)
        img = self.crop_black_border(img, thresh=threshold)
        img = self.crop_fundus_circle(img)
        img = self.center_retina(img)
        img = self.mask_outside_retina(img)
        img = self.gamma_correction(img, gamma=gamma)
        return img

    def gamma_correction(self, img, gamma=0.9):
        img_float = img.astype(np.float32) / 255.0
        # Gamma correction
        img_gamma = np.power(img_float, gamma)
        # Convert back to 0–255 for saving
        img_result = (img_gamma * 255).astype(np.uint8)
        return img_result

    def resize(self, img):
        return cv2.resize(img, 
                          (self.output_size, self.output_size), 
                          interpolation=cv2.INTER_CUBIC)

    def crop_black_border(self, img, thresh=10):
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        # mask of non-black pixels
        mask = gray > thresh

        if not np.any(mask):
            return img  # fallback safety

        coords = np.column_stack(np.where(mask))
        y_min, x_min = coords.min(axis=0)
        y_max, x_max = coords.max(axis=0)

        return img[y_min:y_max+1, x_min:x_max+1]

    def crop_fundus_circle(self, img):
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        _, th = cv2.threshold(gray, 15, 255, cv2.THRESH_BINARY)

        contours, _ = cv2.findContours(th, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        cnt = max(contours, key=cv2.contourArea)

        x, y, w, h = cv2.boundingRect(cnt)
        return img[y:y+h, x:x+w]

    def mask_outside_retina(self, img):
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        _, th = cv2.threshold(gray, 15, 255, cv2.THRESH_BINARY)

        mask = cv2.morphologyEx(th, cv2.MORPH_CLOSE, np.ones((15,15), np.uint8))
        mask = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)

        return cv2.bitwise_and(img, mask)

    def center_retina(self, img):
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        _, th = cv2.threshold(gray, 15, 255, cv2.THRESH_BINARY)

        contours, _ = cv2.findContours(th, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        cnt = max(contours, key=cv2.contourArea)

        x, y, w, h = cv2.boundingRect(cnt)
        crop = img[y:y+h, x:x+w]

        # pad to square
        h, w = crop.shape[:2]
        size = max(h, w)
        padded = np.zeros((size, size, 3), dtype=crop.dtype)

        y0 = (size - h) // 2
        x0 = (size - w) // 2
        padded[y0:y0+h, x0:x0+w] = crop

        return padded


    def apply_clahe(self, image):
        """
            Apply CLAHE contrast enhancement
            This is a bit controversial as some suggested it, while others said it make it worse
        """
        # Convert to LAB color space
        lab = cv2.cvtColor(image, cv2.COLOR_RGB2LAB)
        l_channel, a, b = cv2.split(lab)
        
        # Apply CLAHE to L-channel
        clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
        l_channel = clahe.apply(l_channel)
        
        # Merge back
        lab = cv2.merge([l_channel, a, b])
        return cv2.cvtColor(lab, cv2.COLOR_LAB2RGB)
    
    def process_folder(self, input_folder, output_folder, skip_if_exist, extension=".jpg"):
        """
        Process all images in a folder
        """
        input_folder = Path(input_folder)
        output_folder = Path(output_folder)
        output_folder.mkdir(parents=True, exist_ok=True)
        
        image_files = list(input_folder.glob(f"*{extension}"))
        print(f"Found {len(image_files)} images to process")
        
        for img_path in image_files:
            output_path = output_folder / img_path.name
            try:
                self.process(img_path, output_path, skip_if_exist=skip_if_exist)
            except Exception as e:
                print(f"Error processing {img_path.name}: {e}")

# Initialize processor
#processor = ODIRImageProcessor(output_size=512)

# Process single image
#processor.process(
#    input_path="path/to/your/image.jpg",
#    output_path="path/to/save/processed_image.jpg"
#)

# OR process entire folder
# processor.process_folder(
#     input_folder="path/to/images",
#     output_folder="path/to/processed_images"
# )

# %% [markdown]
# Test on 1 image and then dispaly and compare

# %%
# !mkdir -p ODIR-2019/YOLO/processed_512g_merged

# %%
import os
input_folder="ODIR-2019/YOLO/preprocessed_merged"
output_folder="ODIR-2019/YOLO/processed_512g_merged"
processor = ODIRImageProcessor(output_size=512)

for root, dirs, files in os.walk(input_folder):
    for dir_name in dirs:
        source_dir=os.path.join(root, dir_name)
        target_dir=source_dir.replace(input_folder, output_folder)
        os.makedirs(target_dir, exist_ok=True)
        processor.process_folder(
            input_folder=source_dir,
            output_folder=target_dir,
            skip_if_exist=True,
            extension=".jpg"
        )
        processor.process_folder(
            input_folder=source_dir,
            output_folder=target_dir,
            skip_if_exist=True,
            extension=".png"
        )
# Out:
# Found 0 images to process
# Found 0 images to process
# Found 0 images to process
# Found 0 images to process
# Found 0 images to process
# Found 0 images to process
# Found 26 images to process
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/cataract/2108_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/cataract/294_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/cataract/0_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/cataract/2150_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/cataract/2159_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/cataract/1435_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/cataract/330_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/cataract/2243_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/cataract/2130_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/cataract/2183_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/cataract/726_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/cataract/2219_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/cataract/2227_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/cataract/2106_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/cataract/2208_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/cataract/2125_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/cataract/2185_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/cataract/2213_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/cataract/1415_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/cataract/2156_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/cataract/1454_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/cataract/1164_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/cataract/2198_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/cataract/2216_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/cataract/2262_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/cataract/2144_left.jpg
# Found 0 images to process
# Found 28 images to process
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/glaucoma/1503_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/glaucoma/1239_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/glaucoma/1371_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/glaucoma/1248_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/glaucoma/1473_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/glaucoma/1306_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/glaucoma/1963_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/glaucoma/1405_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/glaucoma/1964_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/glaucoma/1218_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/glaucoma/1319_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/glaucoma/1495_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/glaucoma/1492_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/glaucoma/1369_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/glaucoma/1345_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/glaucoma/1465_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/glaucoma/1222_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/glaucoma/1214_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/glaucoma/1425_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/glaucoma/1406_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/glaucoma/1215_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/glaucoma/1388_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/glaucoma/1439_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/glaucoma/1247_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/glaucoma/1267_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/glaucoma/1229_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/glaucoma/1220_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/glaucoma/1227_left.jpg
# Found 0 images to process
# Found 68 images to process
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/1080_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/1016_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/125_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/816_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/1681_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/661_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/483_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/665_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/510_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/1264_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/611_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/865_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/287_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/1176_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/644_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/1032_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/180_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/883_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/517_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/491_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/357_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/969_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/749_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/269_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/204_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/575_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/858_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/360_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/1120_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/1124_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/487_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/670_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/747_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/545_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/1116_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/1109_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/1383_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/660_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/542_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/643_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/1015_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/573_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/1097_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/2034_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/676_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/880_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/554_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/52_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/858_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/680_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/602_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/496_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/326_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/1019_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/511_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/881_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/460_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/344_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/278_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/286_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/231_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/1674_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/930_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/710_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/165_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/304_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/657_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/other/450_left.jpg
# Found 0 images to process
# Found 13 images to process
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/hypertension/783_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/hypertension/4592_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/hypertension/4579_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/hypertension/499_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/hypertension/790_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/hypertension/675_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/hypertension/2052_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/hypertension/4562_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/hypertension/62_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/hypertension/1045_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/hypertension/355_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/hypertension/116_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/hypertension/983_left.jpg
# Found 0 images to process
# Found 160 images to process
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4304_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/794_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4558_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/309_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/755_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/1068_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/492_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4599_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/604_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4443_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4174_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/446_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4054_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4608_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/2262_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/445_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4247_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4584_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4636_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4629_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4532_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4404_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4035_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4090_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/1205_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4564_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4551_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4063_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4504_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/392_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/209_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/947_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4675_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4452_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4610_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4160_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4321_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4433_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4563_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4297_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/3943_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/920_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/703_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/1136_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/148_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4479_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4105_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/556_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/47_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4401_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4174_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/3949_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/3996_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/221_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/462_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4673_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4508_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4260_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4357_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4072_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4277_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/763_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/3962_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4574_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/386_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4568_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4611_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/507_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4262_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/654_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/361_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4106_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4195_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/881_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4624_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4375_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4650_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4615_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/3969_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4227_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/479_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4477_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4164_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/518_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/703_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4491_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/3965_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4005_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4338_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4123_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4111_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4127_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/791_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4479_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/1482_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/207_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4094_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4171_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4099_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/340_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/44_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/808_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4471_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/186_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4068_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/3958_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4670_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/489_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/206_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/268_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4585_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/308_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/944_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4097_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/2010_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4289_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/50_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4402_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4593_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4630_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4544_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4245_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/296_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/415_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4516_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4331_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4450_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/791_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4160_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/67_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/338_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/229_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4502_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4093_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4061_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/446_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4162_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4567_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4585_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4603_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/537_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4199_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/569_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4388_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/397_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4318_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4304_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4566_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4478_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/697_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/3979_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/718_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/2_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/3936_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/634_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/972_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4524_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4258_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/4557_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/diabetes/593_right.jpg
# Found 0 images to process
# Found 27 images to process
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/ageing/260_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/ageing/514_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/ageing/808_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/ageing/1844_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/ageing/1854_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/ageing/1098_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/ageing/1886_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/ageing/1314_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/ageing/243_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/ageing/359_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/ageing/424_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/ageing/719_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/ageing/419_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/ageing/610_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/ageing/1892_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/ageing/1880_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/ageing/1893_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/ageing/788_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/ageing/1154_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/ageing/1884_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/ageing/788_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/ageing/1831_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/ageing/1856_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/ageing/1836_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/ageing/1243_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/ageing/1873_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/ageing/212_left.jpg
# Found 0 images to process
# Found 23 images to process
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/myopia/1547_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/myopia/567_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/myopia/1607_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/myopia/1349_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/myopia/831_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/myopia/1576_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/myopia/1534_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/myopia/1530_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/myopia/1533_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/myopia/1615_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/myopia/1630_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/myopia/1594_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/myopia/390_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/myopia/16_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/myopia/1677_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/myopia/1686_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/myopia/1694_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/myopia/504_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/myopia/1612_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/myopia/1528_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/myopia/1589_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/myopia/1552_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/myopia/1571_left.jpg
# Found 0 images to process
# Found 282 images to process
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2965_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3103_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/4408_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/190_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2991_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/1296_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2612_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2618_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2973_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/824_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2960_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2437_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2822_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3285_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2600_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2716_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2821_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/606_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/4671_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/1663_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2687_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2661_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3248_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/4027_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/8_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/147_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2542_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3185_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2412_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3058_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3441_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3201_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2475_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3165_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3169_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3260_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/1503_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2994_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2191_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2394_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2410_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/933_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3014_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/653_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2811_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3299_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3401_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2537_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2519_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2796_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3337_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3435_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/1019_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3347_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2172_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2684_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/1173_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2388_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2673_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2920_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/536_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3297_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/486_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2353_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2644_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3043_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3100_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/809_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/4417_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2786_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3374_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3217_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/4614_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3083_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3005_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3198_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3275_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2511_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2460_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3212_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2484_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/4556_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2339_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3245_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3335_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2869_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2849_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/4114_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3002_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2636_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2917_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/124_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2549_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2794_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/1097_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3091_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2991_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3140_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3334_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3042_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/896_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/4302_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2984_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/977_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3943_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2484_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2834_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2879_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2492_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2420_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/437_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2563_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/4146_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3199_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3016_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3403_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/922_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2237_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2632_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3364_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/4361_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2451_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2553_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3363_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3351_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/4642_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3242_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2193_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3267_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2628_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3400_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2675_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2196_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/4038_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/69_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2548_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2683_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/1489_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2880_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2969_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2408_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2628_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3397_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3324_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/4290_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3090_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/3293_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2873_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/val/normal/2602_left.jpg
# ...
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3115_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2405_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2745_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2424_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2888_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2626_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2654_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2898_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3262_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/294_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/1975_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2443_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/689_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/1028_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3088_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/4200_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2368_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3172_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2563_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2673_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3143_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2736_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2892_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2792_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2877_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2367_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3448_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2860_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3202_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/461_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2549_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2764_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3338_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/457_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/363_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/227_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/33_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2827_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3445_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3040_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/252_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2392_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/4638_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2936_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2749_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2761_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2336_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2389_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2919_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2845_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3131_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2160_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/4063_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2499_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/945_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3071_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3227_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2899_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2676_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2477_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2383_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2407_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2778_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2609_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2907_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3216_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2574_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/1242_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/840_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/4272_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3221_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/394_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/701_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/1498_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2819_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3970_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/800_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2678_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2561_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3079_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2974_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2569_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3149_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3177_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/4194_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3323_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/4036_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3347_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2414_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2739_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/391_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/233_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3025_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3193_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2409_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3166_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/60_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2647_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2917_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/4322_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3427_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3317_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/1191_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/4438_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/4076_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/501_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/107_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2958_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2853_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3000_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3229_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/4182_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2364_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2976_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2763_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/846_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3127_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2361_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2399_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2911_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2626_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2942_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3328_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/303_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/8_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3151_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3392_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2886_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2782_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2400_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3062_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2393_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2556_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3174_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2892_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2422_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3068_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/756_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2511_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3211_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3321_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2441_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2948_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3057_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2955_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3027_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2635_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2542_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3275_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2793_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3448_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/4576_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2506_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2740_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2899_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2518_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3121_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2914_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2623_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2770_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/189_left.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3257_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/2583_right.jpg
# Skip as processed image existed: ODIR-2019/YOLO/processed_512g_merged/train/normal/3341_left.jpg
# Found 0 images to process
