# %% [markdown]
# # Processing Images
#
# Here we enhance the images (training and testing) to improve the image quality.
#
# The processing steps:
# 1. Reads the input image
# 2. Converts from BGR to RGB
# 3. Resizes to specified dimensions (256x256) # we choose this for speed in training given we train in local machine, ideally we should use 512x512
# 4. Crop black border around retina:
#     - ODIR images have large black margins → waste resolution.
# 5. Center the retina
#     - More consistent images
# 6. Mask outside retina :
#     - Removes corner glare
#     - Removes camera borders
#     - Keeps retinal signal intact
# 5. Saves the processed
#
# ```python
#     def preprocess_image(self, img):
#         img = self.resize(img)
#         img = self.crop_black_border(img)
#         img = self.center_retina(img)
#         img = self.mask_outside_retina(img)
#         return img
# ```

# %% [markdown]
# Define display images function

# %%
import os
import cv2
from matplotlib import pyplot as plt
def display_images(image_filenames:list[str], title="Image DataSet", col_count = 10):
    plt.suptitle(title, fontsize=20)
    img_count = len(image_filenames)
    plt.figure(figsize=(15, 15))
    for i in range(1, img_count+1):
        plt.subplot(5, col_count, i)
        image_path=image_filenames[i-1]
        image_name=os.path.basename(image_path)
        img = cv2.imread(image_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        plt.imshow(img, aspect="auto")
        plt.title(f"{image_name}")
        plt.axis(False)
    plt.show();

# %% [markdown]
# Define our image processor class

# %%
import cv2
import numpy as np
from pathlib import Path

class ODIRImageProcessor:
    """Simple processor for ODIR retinal images"""
    
    def __init__(self, output_size=512):
        self.output_size = output_size
    
    def process(self, input_path, output_path=None, skip_if_exist=True, apply_clahe=False, threshold=10):
        """
        Process a single ODIR image
        
        Args:
            input_path: Path to input image
            output_path: Optional path to save result. If None, returns image array
        
        Returns:
            Processed image as numpy array
        """
        if skip_if_exist and output_path is not None:
            if os.path.exists(output_path):
                print(f"Skip as processed image existed: {output_path}")
                return

        # Read image
        img = cv2.imread(str(input_path))
        if img is None:
            raise ValueError(f"Cannot read image: {input_path}")
        
        # Convert BGR to RGB
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        
        # Call Preprocess script
        img = self.preprocess_image(img, apply_clahe=apply_clahe, threshold=threshold)

        # Convert back to BGR for saving/display
        img_bgr = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        
        # Save if output path is provided
        if output_path:
            cv2.imwrite(str(output_path), img_bgr)
            print(f"Saved processed image to: {output_path}")
        
       # return img_bgr
    def preprocess_image(self, img, apply_clahe=False, threshold=10):
        img = self.resize(img)
        img = self.crop_black_border(img, thresh=threshold)
        img = self.crop_fundus_circle(img)
        img = self.center_retina(img)
        img = self.mask_outside_retina(img)
        if apply_clahe:
            img = self.apply_clahe(img)
        return img

    def resize(self, img):
        return cv2.resize(img, 
                          (self.output_size, self.output_size), 
                          interpolation=cv2.INTER_CUBIC)

    def crop_black_border(self, img, thresh=10):
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        # mask of non-black pixels
        mask = gray > thresh

        if not np.any(mask):
            return img  # fallback safety

        coords = np.column_stack(np.where(mask))
        y_min, x_min = coords.min(axis=0)
        y_max, x_max = coords.max(axis=0)

        return img[y_min:y_max+1, x_min:x_max+1]

    def crop_fundus_circle(self, img):
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        _, th = cv2.threshold(gray, 15, 255, cv2.THRESH_BINARY)

        contours, _ = cv2.findContours(th, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        cnt = max(contours, key=cv2.contourArea)

        x, y, w, h = cv2.boundingRect(cnt)
        return img[y:y+h, x:x+w]

    def mask_outside_retina(self, img):
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        _, th = cv2.threshold(gray, 15, 255, cv2.THRESH_BINARY)

        mask = cv2.morphologyEx(th, cv2.MORPH_CLOSE, np.ones((15,15), np.uint8))
        mask = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)

        return cv2.bitwise_and(img, mask)

    def center_retina(self, img):
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        _, th = cv2.threshold(gray, 15, 255, cv2.THRESH_BINARY)

        contours, _ = cv2.findContours(th, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        cnt = max(contours, key=cv2.contourArea)

        x, y, w, h = cv2.boundingRect(cnt)
        crop = img[y:y+h, x:x+w]

        # pad to square
        h, w = crop.shape[:2]
        size = max(h, w)
        padded = np.zeros((size, size, 3), dtype=crop.dtype)

        y0 = (size - h) // 2
        x0 = (size - w) // 2
        padded[y0:y0+h, x0:x0+w] = crop

        return padded


    def apply_clahe(self, image):
        """
            Apply CLAHE contrast enhancement
            This is a bit controversial as some suggested it, while others said it make it worse
        """
        # Convert to LAB color space
        lab = cv2.cvtColor(image, cv2.COLOR_RGB2LAB)
        l_channel, a, b = cv2.split(lab)
        
        # Apply CLAHE to L-channel
        clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
        l_channel = clahe.apply(l_channel)
        
        # Merge back
        lab = cv2.merge([l_channel, a, b])
        return cv2.cvtColor(lab, cv2.COLOR_LAB2RGB)
    
    def process_folder(self, input_folder, output_folder, skip_if_exist, extension=".jpg"):
        """
        Process all images in a folder
        """
        input_folder = Path(input_folder)
        output_folder = Path(output_folder)
        output_folder.mkdir(parents=True, exist_ok=True)
        
        image_files = list(input_folder.glob(f"*{extension}"))
        print(f"Found {len(image_files)} images to process")
        
        for img_path in image_files:
            output_path = output_folder / img_path.name
            try:
                self.process(img_path, output_path, skip_if_exist=skip_if_exist)
            except Exception as e:
                print(f"Error processing {img_path.name}: {e}")

# Initialize processor
#processor = ODIRImageProcessor(output_size=512)

# Process single image
#processor.process(
#    input_path="path/to/your/image.jpg",
#    output_path="path/to/save/processed_image.jpg"
#)

# OR process entire folder
# processor.process_folder(
#     input_folder="path/to/images",
#     output_folder="path/to/processed_images"
# )

# %% [markdown]
# Test on 1 image and then dispaly and compare

# %%
import os
input_folder="ODIR-2019/preprocessed_images"
output_folder="ODIR-2019/processed_512_images"
input_image=f"{input_folder}/1494_left.jpg"
output_image=f"/tmp/1494_left.jpg"
os.makedirs(output_folder, exist_ok=True)
processor = ODIRImageProcessor(output_size=512)
processor.process(input_image, "/tmp/no_clahe.jpg", skip_if_exist=False, apply_clahe=False)
processor.process(input_image, "/tmp/no_c_t80.jpg", skip_if_exist=False, apply_clahe=False, threshold=80)
processor.process(input_image, "/tmp/no_c_t100.jpg", skip_if_exist=False, apply_clahe=False, threshold=100)
processor.process(input_image, "/tmp/clahe.jpg", skip_if_exist=False, apply_clahe=True)
images=[input_image, "/tmp/no_clahe.jpg","/tmp/clahe.jpg","/tmp/no_c_t80.jpg","/tmp/no_c_t100.jpg"]
display_images(images);
# Out:
# Saved processed image to: /tmp/no_clahe.jpg
# Saved processed image to: /tmp/no_c_t80.jpg
# Saved processed image to: /tmp/no_c_t100.jpg
# Saved processed image to: /tmp/clahe.jpg

# %% [markdown]
# We can see from above that our image processing  work without changing much of the image
#
# However, clahe added a lot of extra details that may or may not work well
# Also choosing more agressive threshold may cause image to be cropped/deformed unnecessarily
#
# Let us be safe and conservative.
# We shall do the minimal and safe preprocessing for all the images without clahe and low threshold=10

# %%
processor.process_folder(input_folder, output_folder, skip_if_exist=True)
# Out:
# Found 6392 images to process
# Saved processed image to: ODIR-2019/processed_512_images/2750_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2417_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/4304_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/4631_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2817_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2346_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/3363_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/3009_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2902_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/1196_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/4238_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2065_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/3163_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/841_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2993_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/4321_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/794_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2209_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2162_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2165_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/
left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2393_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/1228_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/4524_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2556_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/4258_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/1266_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/3174_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/4097_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2892_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2422_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/4113_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/3068_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/756_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2511_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/1160_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/691_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/992_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/3211_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/264_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/1853_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/3321_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/4650_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2441_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2948_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/3057_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2434_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/1885_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/4615_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/4334_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/140_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2955_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/3272_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/3027_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2635_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/1210_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/796_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/352_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/570_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2542_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/304_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/4461_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/305_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2568_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/1059_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/1414_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/62_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/876_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/3275_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2793_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/630_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/126_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/3448_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2155_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/345_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/4507_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/3999_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/4576_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/497_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/3948_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2506_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/4022_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/838_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2740_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2899_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2518_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/1012_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/3121_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2096_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2914_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/657_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/4309_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/450_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2623_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2770_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/189_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2504_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/1990_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/4358_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/139_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/1103_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/4557_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/93_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/3257_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/593_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/299_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/3362_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/562_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/2583_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/3952_right.jpg
# Saved processed image to: ODIR-2019/processed_512_images/3341_left.jpg
# Saved processed image to: ODIR-2019/processed_512_images/130_left.jpg

# %%
import os
import cv2
import pandas as pd
import math

def sample_images(train_data, sample_count):
    return train_data.groupby('label_detail').apply(lambda x: x.sample(sample_count)).reset_index(drop=True)

def view_random_images(samples, data_set_img_folder, title):
    images_path = list(samples['filename'])
    labels = list(samples['label_detail'])
    samples_count = len(samples)
    class_count=8
    num_rows=math.ceil(samples_count/class_count)
    plt.figure(figsize=(class_count*2, num_rows*2))
    plt.suptitle(title, fontsize=14)
    for i in range(1, samples_count+1):
        plt.subplot(num_rows,class_count , i)
        image_path=os.path.join(data_set_img_folder, images_path[i-1])
        img = cv2.imread(image_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        plt.imshow(img, aspect="auto")
        plt.title(f"{labels[i-1]}-{images_path[i-1].split('/')[-1]}", fontsize=8)
        plt.axis(False);
    plt.show()
result_datapath="ODIR-2019/results"
train_df = pd.read_csv(os.path.join(result_datapath, '01_eda_train_df.csv'))
samples = sample_images(train_df, 2)
samples
#view_random_images(train_df, input_folder, "Before Processing")
#view_random_images(train_df, output_folder, "After Processing")
# Out:
# /tmp/ipykernel_80060/2444207367.py:7: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return train_data.groupby('label_detail').apply(lambda x: x.sample(sample_count)).reset_index(drop=True)
#           filename  label_detail                                     keywords  \
# 0     126_left.jpg        ageing         dry age-related macular degeneration
# 1   1111_right.jpg        ageing         dry age-related macular degeneration
# 2    1468_left.jpg      cataract                                     cataract
# 3    2210_left.jpg      cataract                                     cataract
# 4    4191_left.jpg      diabetes          severe nonproliferative retinopathy
# 5   4318_right.jpg      diabetes       moderate non proliferative retinopathy
# 6   2048_right.jpg      glaucoma  glaucoma old central retinal vein occlusion
# 7   1443_right.jpg      glaucoma                                     glaucoma
# 8    4478_left.jpg  hypertension                     hypertensive retinopathy
# 9     499_left.jpg  hypertension                     hypertensive retinopathy
# 10    741_left.jpg        myopia                          pathological myopia
# 11   1563_left.jpg        myopia                          pathological myopia
# 12  2415_right.jpg        normal                                normal fundus
# 13    591_left.jpg        normal                                normal fundus
# 14   766_right.jpg         other                  macular epiretinal membrane
# 15    97_right.jpg         other                        vitreous degeneration
#
#    label
# 0      A
# 1      A
# 2      C
# 3      C
# 4      D
# 5      D
# 6      G
# 7      G
# 8      H
# 9      H
# 10     M
# 11     M
# 12     N
# 13     N
# 14     O
# 15     O

# %%
view_random_images(samples, input_folder, "Before Processing")

# %%
view_random_images(samples, output_folder, "After Processing")
