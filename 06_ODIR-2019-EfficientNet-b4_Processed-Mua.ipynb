# %% [markdown]
# # EfficientNet-B4 Processed Merged Usuyama
#
#
# Here we run experiment with ODIR-2019 Usuyama enhanced Processed images and additional training images from Ocular Diseases DataSet
# except for Normal which we leave the ODIR-2019 original images as it is
#
# our previous experiment was using wrong usuyama method
# use this instead
# https://github.com/usuyama/pydata-medical-image/blob/master/diabetic_retinopathy/notebooks/1_preprocess.ipynb

# %%
data_dir = './ODIR-2019/YOLO/processed_512ua_merged'  # Your dataset path
model_name = 'efficientnet-b4'
saved_model_name = 'efficientnet-b4-odir-2019-pmua.pth'
wandb_project = "odir-2019"
wandb_run_name = 'efficientnet-b4_pmua'

# %% [markdown]
# The following codes are generic or the same across experiments

# %%
# %%capture
# !pip install efficientnet-pytorch wandb torch torchvision scikit-learn seaborn tqdm

# %%
import sys
sys.path.append('.')

from efficient_net import EfficientNetTrainer

# %%
from util import get_train_device

device_for_training = get_train_device()
# Out:
# Using NVIDIA GPU (CUDA)

# %%
import wandb
config = {
    'data_dir': data_dir,
    'model_name': model_name,
    'num_classes': 8,
    'image_size': 512,
    'batch_size': 16,  # Smaller for Jupyter
    'epochs': 30,
    'lr': 0.001,
    'weight_decay': 1e-4,
    'optimizer': 'adamw',
    'scheduler': 'cosine',
    'fine_tune': True,
    'unfreeze_blocks': 3,
    'label_smoothing': 0.1,
    'num_workers': 2,  # Lower for Jupyter
    'use_amp': True,
    'seed': 42
}
wandb.init(project=wandb_project, name=wandb_run_name, config=config)
trainer = EfficientNetTrainer(config)
trainer.train()
# Out:
# wandb: Currently logged in as: raymond-samalo (samalo) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260224_121349-do2zp3eb</code>
# Syncing run <strong><a href='https://wandb.ai/samalo/odir-2019/runs/do2zp3eb' target="_blank">efficientnet-b4_pmua</a></strong> to <a href='https://wandb.ai/samalo/odir-2019' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/samalo/odir-2019' target="_blank">https://wandb.ai/samalo/odir-2019</a>
#  View run at <a href='https://wandb.ai/samalo/odir-2019/runs/do2zp3eb' target="_blank">https://wandb.ai/samalo/odir-2019/runs/do2zp3eb</a>
# Using device: cuda
# Loading efficientnet-b4 with 8 classes...
# Loaded pretrained weights for efficientnet-b4
# Loading datasets from ./ODIR-2019/YOLO/processed_512ua_merged...
# Found 9478 images in train split across 8 classes
#
# Class distribution in train split:
#   normal: 2252 samples (23.8%)
#   diabetes: 2790 samples (29.4%)
#   glaucoma: 1574 samples (16.6%)
#   cataract: 724 samples (7.6%)
#   ageing: 724 samples (7.6%)
#   hypertension: 394 samples (4.2%)
#   myopia: 475 samples (5.0%)
#   other: 545 samples (5.8%)
# Found 627 images in val split across 8 classes
#
# Class distribution in val split:
#   normal: 282 samples (45.0%)
#   diabetes: 160 samples (25.5%)
#   glaucoma: 28 samples (4.5%)
#   cataract: 26 samples (4.1%)
#   ageing: 27 samples (4.3%)
#   hypertension: 13 samples (2.1%)
#   myopia: 23 samples (3.7%)
#   other: 68 samples (10.8%)
# Found 627 images in test split across 8 classes
#
# Class distribution in test split:
#   normal: 282 samples (45.0%)
#   diabetes: 160 samples (25.5%)
#   glaucoma: 28 samples (4.5%)
#   cataract: 27 samples (4.3%)
#   ageing: 26 samples (4.1%)
#   hypertension: 13 samples (2.1%)
#   myopia: 23 samples (3.7%)
#   other: 68 samples (10.8%)
#
# 📊 Dataset Statistics:
#    Train samples: 9478
#    Val samples:   627
#    Test samples:  627
#    Image size:    512
#    Batch size:    16
#
# ============================================================
# Epoch 1/30
# ============================================================
# Epoch 1 Training: 100%|██████████| 592/592 [04:29<00:00,  2.19it/s, Loss=1.3017, Acc=60.49%, LR=1.00e-04]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.3780, Acc=58.53%]
# 📊 Epoch 1 Summary:
# Train - Loss: 1.3017, Acc: 60.49%, F1: 0.5824
# Val   - Loss: 1.3780, Acc: 58.53%, F1: 0.5431
# Learning Rate: 9.97e-05
#   Time - Epoch: 299.2s, Inference: 17.0ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260224_121349-do2zp3eb/files/best_model.pth
# ✅ New best model saved with F1: 0.5431
#
# ============================================================
# Epoch 2/30
# ============================================================
# Epoch 2 Training: 100%|██████████| 592/592 [04:24<00:00,  2.23it/s, Loss=1.1492, Acc=66.17%, LR=9.97e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.3378, Acc=60.77%]
# 📊 Epoch 2 Summary:
# Train - Loss: 1.1492, Acc: 66.17%, F1: 0.6473
# Val   - Loss: 1.3378, Acc: 60.77%, F1: 0.5567
# Learning Rate: 9.89e-05
#   Time - Epoch: 294.3s, Inference: 9.8ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260224_121349-do2zp3eb/files/best_model.pth
# ✅ New best model saved with F1: 0.5567
#
# ============================================================
# Epoch 3/30
# ============================================================
# Epoch 3 Training: 100%|██████████| 592/592 [04:23<00:00,  2.24it/s, Loss=1.1007, Acc=68.11%, LR=9.89e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2749, Acc=64.59%]
# 📊 Epoch 3 Summary:
# Train - Loss: 1.1007, Acc: 68.11%, F1: 0.6683
# Val   - Loss: 1.2749, Acc: 64.59%, F1: 0.6176
# Learning Rate: 9.76e-05
#   Time - Epoch: 293.3s, Inference: 9.5ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260224_121349-do2zp3eb/files/best_model.pth
# ✅ New best model saved with F1: 0.6176
#
# ============================================================
# Epoch 4/30
# ============================================================
# Epoch 4 Training: 100%|██████████| 592/592 [04:24<00:00,  2.24it/s, Loss=1.0742, Acc=69.23%, LR=9.76e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2677, Acc=63.32%]
# 📊 Epoch 4 Summary:
# Train - Loss: 1.0742, Acc: 69.23%, F1: 0.6833
# Val   - Loss: 1.2677, Acc: 63.32%, F1: 0.6192
# Learning Rate: 9.57e-05
#   Time - Epoch: 293.9s, Inference: 10.4ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260224_121349-do2zp3eb/files/best_model.pth
# ✅ New best model saved with F1: 0.6192
#
# ============================================================
# Epoch 5/30
# ============================================================
# Epoch 5 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=1.0436, Acc=70.50%, LR=9.57e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2708, Acc=63.80%]
# 📊 Epoch 5 Summary:
# Train - Loss: 1.0436, Acc: 70.50%, F1: 0.6973
# Val   - Loss: 1.2708, Acc: 63.80%, F1: 0.6148
# Learning Rate: 9.34e-05
#   Time - Epoch: 294.5s, Inference: 9.9ms
#
# ============================================================
# Epoch 6/30
# ============================================================
# Epoch 6 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=1.0222, Acc=71.24%, LR=9.34e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2663, Acc=65.23%]
# 📊 Epoch 6 Summary:
# Train - Loss: 1.0222, Acc: 71.24%, F1: 0.7052
# Val   - Loss: 1.2663, Acc: 65.23%, F1: 0.6241
# Learning Rate: 9.05e-05
#   Time - Epoch: 294.9s, Inference: 10.1ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260224_121349-do2zp3eb/files/best_model.pth
# ✅ New best model saved with F1: 0.6241
#
# ============================================================
# Epoch 7/30
# ============================================================
# Epoch 7 Training: 100%|██████████| 592/592 [04:21<00:00,  2.27it/s, Loss=1.0041, Acc=72.26%, LR=9.05e-05]
# Validation: 100%|██████████| 40/40 [00:28<00:00,  1.40it/s, Loss=1.2181, Acc=66.83%]
# 📊 Epoch 7 Summary:
# Train - Loss: 1.0041, Acc: 72.26%, F1: 0.7162
# Val   - Loss: 1.2181, Acc: 66.83%, F1: 0.6465
# Learning Rate: 8.73e-05
#   Time - Epoch: 289.5s, Inference: 9.8ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260224_121349-do2zp3eb/files/best_model.pth
# ✅ New best model saved with F1: 0.6465
#
# ============================================================
# Epoch 8/30
# ============================================================
# Epoch 8 Training: 100%|██████████| 592/592 [04:20<00:00,  2.28it/s, Loss=0.9869, Acc=72.51%, LR=8.73e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2075, Acc=66.51%]
# 📊 Epoch 8 Summary:
# Train - Loss: 0.9869, Acc: 72.51%, F1: 0.7186
# Val   - Loss: 1.2075, Acc: 66.51%, F1: 0.6517
# Learning Rate: 8.36e-05
#   Time - Epoch: 289.5s, Inference: 10.0ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260224_121349-do2zp3eb/files/best_model.pth
# ✅ New best model saved with F1: 0.6517
#
# ============================================================
# Epoch 9/30
# ============================================================
# Epoch 9 Training: 100%|██████████| 592/592 [04:24<00:00,  2.23it/s, Loss=0.9797, Acc=73.22%, LR=8.36e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2250, Acc=65.07%]
# 📊 Epoch 9 Summary:
# Train - Loss: 0.9797, Acc: 73.22%, F1: 0.7266
# Val   - Loss: 1.2250, Acc: 65.07%, F1: 0.6425
# Learning Rate: 7.96e-05
#   Time - Epoch: 294.4s, Inference: 10.5ms
#
# ============================================================
# Epoch 10/30
# ============================================================
# Epoch 10 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.9528, Acc=74.73%, LR=7.96e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2457, Acc=66.19%]
# 📊 Epoch 10 Summary:
# Train - Loss: 0.9528, Acc: 74.73%, F1: 0.7421
# Val   - Loss: 1.2457, Acc: 66.19%, F1: 0.6382
# Learning Rate: 7.52e-05
#   Time - Epoch: 294.5s, Inference: 10.2ms
#
# ============================================================
# Epoch 11/30
# ============================================================
# Epoch 11 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.9436, Acc=74.61%, LR=7.52e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.1762, Acc=67.62%]
# 📊 Epoch 11 Summary:
# Train - Loss: 0.9436, Acc: 74.61%, F1: 0.7415
# Val   - Loss: 1.1762, Acc: 67.62%, F1: 0.6650
# Learning Rate: 7.06e-05
#   Time - Epoch: 294.5s, Inference: 9.9ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260224_121349-do2zp3eb/files/best_model.pth
# ✅ New best model saved with F1: 0.6650
#
# ============================================================
# Epoch 12/30
# ============================================================
# Epoch 12 Training: 100%|██████████| 592/592 [04:21<00:00,  2.26it/s, Loss=0.9349, Acc=75.31%, LR=7.06e-05]
# Validation: 100%|██████████| 40/40 [00:28<00:00,  1.39it/s, Loss=1.2207, Acc=65.71%]
# 📊 Epoch 12 Summary:
# Train - Loss: 0.9349, Acc: 75.31%, F1: 0.7493
# Val   - Loss: 1.2207, Acc: 65.71%, F1: 0.6552
# Learning Rate: 6.58e-05
#   Time - Epoch: 290.6s, Inference: 10.2ms
#
# ============================================================
# Epoch 13/30
# ============================================================
# Epoch 13 Training: 100%|██████████| 592/592 [04:19<00:00,  2.29it/s, Loss=0.9184, Acc=75.96%, LR=6.58e-05]
# Validation: 100%|██████████| 40/40 [00:28<00:00,  1.39it/s, Loss=1.2348, Acc=65.71%]
# 📊 Epoch 13 Summary:
# Train - Loss: 0.9184, Acc: 75.96%, F1: 0.7550
# Val   - Loss: 1.2348, Acc: 65.71%, F1: 0.6532
# Learning Rate: 6.08e-05
#   Time - Epoch: 287.8s, Inference: 9.3ms
#
# ============================================================
# Epoch 14/30
# ============================================================
# Epoch 14 Training: 100%|██████████| 592/592 [04:18<00:00,  2.29it/s, Loss=0.9083, Acc=75.86%, LR=6.08e-05]
# Validation: 100%|██████████| 40/40 [00:28<00:00,  1.39it/s, Loss=1.2501, Acc=66.99%]
# 📊 Epoch 14 Summary:
# Train - Loss: 0.9083, Acc: 75.86%, F1: 0.7549
# Val   - Loss: 1.2501, Acc: 66.99%, F1: 0.6524
# Learning Rate: 5.57e-05
#   Time - Epoch: 287.2s, Inference: 9.7ms
#
# ============================================================
# Epoch 15/30
# ============================================================
# Epoch 15 Training: 100%|██████████| 592/592 [04:20<00:00,  2.27it/s, Loss=0.8976, Acc=76.84%, LR=5.57e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2163, Acc=66.83%]
# 📊 Epoch 15 Summary:
# Train - Loss: 0.8976, Acc: 76.84%, F1: 0.7652
# Val   - Loss: 1.2163, Acc: 66.83%, F1: 0.6569
# Learning Rate: 5.05e-05
#   Time - Epoch: 289.9s, Inference: 10.0ms
#
# ============================================================
# Epoch 16/30
# ============================================================
# Epoch 16 Training: 100%|██████████| 592/592 [04:24<00:00,  2.24it/s, Loss=0.8894, Acc=77.44%, LR=5.05e-05]
# Validation: 100%|██████████| 40/40 [00:28<00:00,  1.40it/s, Loss=1.2273, Acc=66.19%]
# 📊 Epoch 16 Summary:
# Train - Loss: 0.8894, Acc: 77.44%, F1: 0.7718
# Val   - Loss: 1.2273, Acc: 66.19%, F1: 0.6513
# Learning Rate: 4.53e-05
#   Time - Epoch: 293.3s, Inference: 10.0ms
#
# ============================================================
# Epoch 17/30
# ============================================================
# Epoch 17 Training: 100%|██████████| 592/592 [04:26<00:00,  2.23it/s, Loss=0.8756, Acc=78.15%, LR=4.53e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2167, Acc=67.94%]
# 📊 Epoch 17 Summary:
# Train - Loss: 0.8756, Acc: 78.15%, F1: 0.7782
# Val   - Loss: 1.2167, Acc: 67.94%, F1: 0.6707
# Learning Rate: 4.02e-05
#   Time - Epoch: 295.5s, Inference: 9.6ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260224_121349-do2zp3eb/files/best_model.pth
# ✅ New best model saved with F1: 0.6707
#
# ============================================================
# Epoch 18/30
# ============================================================
# Epoch 18 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.8713, Acc=78.62%, LR=4.02e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2490, Acc=64.91%]
# 📊 Epoch 18 Summary:
# Train - Loss: 0.8713, Acc: 78.62%, F1: 0.7834
# Val   - Loss: 1.2490, Acc: 64.91%, F1: 0.6454
# Learning Rate: 3.52e-05
#   Time - Epoch: 295.6s, Inference: 9.3ms
#
# ============================================================
# Epoch 19/30
# ============================================================
# Epoch 19 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.8594, Acc=78.86%, LR=3.52e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2321, Acc=66.67%]
# 📊 Epoch 19 Summary:
# Train - Loss: 0.8594, Acc: 78.86%, F1: 0.7866
# Val   - Loss: 1.2321, Acc: 66.67%, F1: 0.6618
# Learning Rate: 3.04e-05
#   Time - Epoch: 295.6s, Inference: 9.6ms
#
# ============================================================
# Epoch 20/30
# ============================================================
# Epoch 20 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.8597, Acc=78.80%, LR=3.04e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2307, Acc=67.15%]
# 📊 Epoch 20 Summary:
# Train - Loss: 0.8597, Acc: 78.80%, F1: 0.7860
# Val   - Loss: 1.2307, Acc: 67.15%, F1: 0.6591
# Learning Rate: 2.58e-05
#   Time - Epoch: 295.6s, Inference: 9.4ms
#
# ============================================================
# Epoch 21/30
# ============================================================
# Epoch 21 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.8458, Acc=79.73%, LR=2.58e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2404, Acc=66.99%]
# 📊 Epoch 21 Summary:
# Train - Loss: 0.8458, Acc: 79.73%, F1: 0.7943
# Val   - Loss: 1.2404, Acc: 66.99%, F1: 0.6592
# Learning Rate: 2.14e-05
#   Time - Epoch: 295.6s, Inference: 9.7ms
#
# ============================================================
# Epoch 22/30
# ============================================================
# Epoch 22 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.8499, Acc=79.20%, LR=2.14e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2352, Acc=66.83%]
# 📊 Epoch 22 Summary:
# Train - Loss: 0.8499, Acc: 79.20%, F1: 0.7897
# Val   - Loss: 1.2352, Acc: 66.83%, F1: 0.6598
# Learning Rate: 1.74e-05
#   Time - Epoch: 295.6s, Inference: 9.6ms
#
# ============================================================
# Epoch 23/30
# ============================================================
# Epoch 23 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.8317, Acc=80.26%, LR=1.74e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2218, Acc=66.19%]
# 📊 Epoch 23 Summary:
# Train - Loss: 0.8317, Acc: 80.26%, F1: 0.8006
# Val   - Loss: 1.2218, Acc: 66.19%, F1: 0.6518
# Learning Rate: 1.37e-05
#   Time - Epoch: 295.6s, Inference: 9.6ms
#
# ============================================================
# Epoch 24/30
# ============================================================
# Epoch 24 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.8276, Acc=80.60%, LR=1.37e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2413, Acc=65.71%]
# 📊 Epoch 24 Summary:
# Train - Loss: 0.8276, Acc: 80.60%, F1: 0.8038
# Val   - Loss: 1.2413, Acc: 65.71%, F1: 0.6531
# Learning Rate: 1.05e-05
#   Time - Epoch: 295.6s, Inference: 9.5ms
#
# ============================================================
# Epoch 25/30
# ============================================================
# Epoch 25 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.8343, Acc=80.45%, LR=1.05e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2404, Acc=66.99%]
# 📊 Epoch 25 Summary:
# Train - Loss: 0.8343, Acc: 80.45%, F1: 0.8028
# Val   - Loss: 1.2404, Acc: 66.99%, F1: 0.6633
# Learning Rate: 7.63e-06
#   Time - Epoch: 295.6s, Inference: 9.4ms
#
# ============================================================
# Epoch 26/30
# ============================================================
# Epoch 26 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.8231, Acc=80.80%, LR=7.63e-06]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2486, Acc=65.55%]
# 📊 Epoch 26 Summary:
# Train - Loss: 0.8231, Acc: 80.80%, F1: 0.8052
# Val   - Loss: 1.2486, Acc: 65.55%, F1: 0.6518
# Learning Rate: 5.28e-06
#   Time - Epoch: 295.6s, Inference: 10.0ms
#
# ============================================================
# Epoch 27/30
# ============================================================
# Epoch 27 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.8248, Acc=80.52%, LR=5.28e-06]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.2516, Acc=66.67%]
# 📊 Epoch 27 Summary:
# Train - Loss: 0.8248, Acc: 80.52%, F1: 0.8036
# Val   - Loss: 1.2516, Acc: 66.67%, F1: 0.6615
# Learning Rate: 3.42e-06
#   Time - Epoch: 295.6s, Inference: 10.8ms
#
# ============================================================
# Epoch 28/30
# ============================================================
# Epoch 28 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.8231, Acc=80.62%, LR=3.42e-06]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2550, Acc=66.83%]
# 📊 Epoch 28 Summary:
# Train - Loss: 0.8231, Acc: 80.62%, F1: 0.8044
# Val   - Loss: 1.2550, Acc: 66.83%, F1: 0.6640
# Learning Rate: 2.08e-06
#   Time - Epoch: 294.9s, Inference: 10.4ms
#
# ============================================================
# Epoch 29/30
# ============================================================
# Epoch 29 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.8175, Acc=80.64%, LR=2.08e-06]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2561, Acc=66.51%]
# 📊 Epoch 29 Summary:
# Train - Loss: 0.8175, Acc: 80.64%, F1: 0.8046
# Val   - Loss: 1.2561, Acc: 66.51%, F1: 0.6608
# Learning Rate: 1.27e-06
#   Time - Epoch: 294.9s, Inference: 9.7ms
#
# ============================================================
# Epoch 30/30
# ============================================================
# Epoch 30 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.8196, Acc=81.10%, LR=1.27e-06]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2510, Acc=66.35%]
# 📊 Epoch 30 Summary:
# Train - Loss: 0.8196, Acc: 81.10%, F1: 0.8095
# Val   - Loss: 1.2510, Acc: 66.35%, F1: 0.6593
# Learning Rate: 1.00e-06
#   Time - Epoch: 295.0s, Inference: 9.9ms
#
# 🎉 Training completed!
# 📈 Best validation F1: 0.6707
# ⏱️  Average epoch time: 293.9s
# ⚡ Average inference time: 10.1ms

# %%
# cell 6: Test
test_loss, test_acc, test_f1 = trainer.test()
print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}, Test F1: {test_f1:.4f}")
# Out:
# ============================================================
# Testing Model
# ============================================================
# Model loaded from /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260224_121349-do2zp3eb/files/best_model.pth
# Testing: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.1972, Acc=67.94%]
# 📊 Test Results:
# Test Loss: 1.1972
# Test Accuracy: 67.94%
# Test Weighted F1 Score: 0.6603
# Average Inference Time per Image: 9.59 ms
#
# 📋 Detailed Classification Report:
#               precision    recall  f1-score   support
#
#       normal       0.67      0.88      0.76       282
#     diabetes       0.66      0.48      0.56       160
#     glaucoma       0.62      0.54      0.58        28
#     cataract       0.88      0.85      0.87        27
#       ageing       0.72      0.69      0.71        26
# hypertension       0.25      0.08      0.12        13
#       myopia       0.80      0.87      0.83        23
#        other       0.64      0.37      0.47        68
#
#     accuracy                           0.68       627
#    macro avg       0.66      0.59      0.61       627
# weighted avg       0.67      0.68      0.66       627
#
# Test Loss: 1.1972, Test Acc: 67.9426, Test F1: 0.6603

# %%
import os
final_model_path = os.path.join('ODIR-2019/results/', saved_model_name)
trainer.save_model(final_model_path)
# Out:
# Model saved to ODIR-2019/results/efficientnet-b4-odir-2019-pmua.pth

# %%
wandb.finish()
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>learning_rate</td><td>█████▇▇▇▇▆▆▆▅▅▅▄▄▃▃▃▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>test_acc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>train_acc</td><td>▁▃▄▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇█▇████████</td></tr><tr><td>train_f1</td><td>▁▃▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇█▇████████</td></tr><tr><td>train_loss</td><td>█▆▅▅▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▃▆▅▅▆▇▇▆▇█▆▆▇▇▇█▆▇▇▇▇▇▆▇▆▇▇▇▇</td></tr><tr><td>val_f1</td><td>▁▂▅▅▅▅▇▇▆▆█▇▇▇▇▇█▇█▇▇▇▇▇█▇▇█▇▇</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>30</td></tr><tr><td>learning_rate</td><td>0.0</td></tr><tr><td>test_acc</td><td>67.94258</td></tr><tr><td>test_f1</td><td>0.66031</td></tr><tr><td>test_loss</td><td>1.19715</td></tr><tr><td>train_acc</td><td>81.1022</td></tr><tr><td>train_f1</td><td>0.80949</td></tr><tr><td>train_loss</td><td>0.81958</td></tr><tr><td>val_acc</td><td>66.34769</td></tr><tr><td>val_f1</td><td>0.65934</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">efficientnet-b4_pmua</strong> at: <a href='https://wandb.ai/samalo/odir-2019/runs/do2zp3eb' target="_blank">https://wandb.ai/samalo/odir-2019/runs/do2zp3eb</a><br> View project at: <a href='https://wandb.ai/samalo/odir-2019' target="_blank">https://wandb.ai/samalo/odir-2019</a><br>Synced 5 W&B file(s), 9 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260224_121349-do2zp3eb/logs</code>
