# %%
# %%capture
# !pip install efficientnet-pytorch wandb torch torchvision scikit-learn seaborn tqdm

# %%
import sys
sys.path.append('.')

from efficient_net import EfficientNetTrainer

# %%
from util import get_train_device

device_for_training = get_train_device()
# Out:
# Using NVIDIA GPU (CUDA)

# %% [markdown]
# We use EfficientNet-B0 as we want to target edge device

# %%
import wandb
config = {
    'data_dir': './ODIR-2019/YOLO/augmented_512',  # Your dataset path
    'model_name': 'efficientnet-b0',
    'num_classes': 8,
    'image_size': 512,
    'batch_size': 16,  # Smaller for Jupyter
    'epochs': 30,
    'lr': 0.001,
    'weight_decay': 1e-4,
    'optimizer': 'adamw',
    'scheduler': 'cosine',
    'fine_tune': True,
    'unfreeze_blocks': 3,
    'label_smoothing': 0.1,
    'num_workers': 2,  # Lower for Jupyter
    'use_amp': True,
    'seed': 42
}
wandb.init(project="odir-2019", name="efficientnet-b0_augmented_512")
trainer = EfficientNetTrainer(config)
trainer.train()
# Out:
# wandb: Currently logged in as: raymond-samalo (samalo) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260127_080102-0ot6hg82</code>
# Syncing run <strong><a href='https://wandb.ai/samalo/odir-2019/runs/0ot6hg82' target="_blank">efficientnet-b0_augmented_512</a></strong> to <a href='https://wandb.ai/samalo/odir-2019' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/samalo/odir-2019' target="_blank">https://wandb.ai/samalo/odir-2019</a>
#  View run at <a href='https://wandb.ai/samalo/odir-2019/runs/0ot6hg82' target="_blank">https://wandb.ai/samalo/odir-2019/runs/0ot6hg82</a>
# Using device: cuda
# Loading efficientnet-b0 with 8 classes...
# Loaded pretrained weights for efficientnet-b0
# Loading datasets from ./ODIR-2019/YOLO/augmented_512...
# Found 18016 images in train split across 8 classes
#
# Class distribution in train split:
#   normal: 2252 samples (12.5%)
#   diabetes: 2252 samples (12.5%)
#   glaucoma: 2252 samples (12.5%)
#   cataract: 2252 samples (12.5%)
#   ageing: 2252 samples (12.5%)
#   hypertension: 2252 samples (12.5%)
#   myopia: 2252 samples (12.5%)
#   other: 2252 samples (12.5%)
# Found 627 images in val split across 8 classes
#
# Class distribution in val split:
#   normal: 282 samples (45.0%)
#   diabetes: 160 samples (25.5%)
#   glaucoma: 28 samples (4.5%)
#   cataract: 26 samples (4.1%)
#   ageing: 27 samples (4.3%)
#   hypertension: 13 samples (2.1%)
#   myopia: 23 samples (3.7%)
#   other: 68 samples (10.8%)
# Found 627 images in test split across 8 classes
#
# Class distribution in test split:
#   normal: 282 samples (45.0%)
#   diabetes: 160 samples (25.5%)
#   glaucoma: 28 samples (4.5%)
#   cataract: 27 samples (4.3%)
#   ageing: 26 samples (4.1%)
#   hypertension: 13 samples (2.1%)
#   myopia: 23 samples (3.7%)
#   other: 68 samples (10.8%)
#
# ============================================================
# Epoch 1/30
# ============================================================
# Epoch 1 Training: 100%|██████████| 1126/1126 [03:35<00:00,  5.22it/s, Loss=1.4533, Acc=52.15%, LR=1.00e-04]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.43it/s, Loss=1.4601, Acc=50.88%]
# Epoch 1 Summary:
# Train - Loss: 1.4533, Acc: 52.15%, F1: 0.5030
# Val   - Loss: 1.4601, Acc: 50.88%, F1: 0.4934
# Learning Rate: 9.97e-05
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260127_080102-0ot6hg82/files/best_model.pth
# ✅ New best model saved with F1: 0.4934
#
# ============================================================
# Epoch 2/30
# ============================================================
# Epoch 2 Training: 100%|██████████| 1126/1126 [03:30<00:00,  5.34it/s, Loss=1.2575, Acc=62.27%, LR=9.97e-05]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.45it/s, Loss=1.4127, Acc=54.70%]
# Epoch 2 Summary:
# Train - Loss: 1.2575, Acc: 62.27%, F1: 0.6098
# Val   - Loss: 1.4127, Acc: 54.70%, F1: 0.5323
# Learning Rate: 9.89e-05
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260127_080102-0ot6hg82/files/best_model.pth
# ✅ New best model saved with F1: 0.5323
#
# ============================================================
# Epoch 3/30
# ============================================================
# Epoch 3 Training: 100%|██████████| 1126/1126 [03:32<00:00,  5.31it/s, Loss=1.1723, Acc=66.83%, LR=9.89e-05]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.45it/s, Loss=1.3675, Acc=59.17%]
# Epoch 3 Summary:
# Train - Loss: 1.1723, Acc: 66.83%, F1: 0.6592
# Val   - Loss: 1.3675, Acc: 59.17%, F1: 0.5409
# Learning Rate: 9.76e-05
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260127_080102-0ot6hg82/files/best_model.pth
# ✅ New best model saved with F1: 0.5409
#
# ============================================================
# Epoch 4/30
# ============================================================
# Epoch 4 Training: 100%|██████████| 1126/1126 [03:31<00:00,  5.34it/s, Loss=1.1090, Acc=70.12%, LR=9.76e-05]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.45it/s, Loss=1.3753, Acc=61.24%]
# Epoch 4 Summary:
# Train - Loss: 1.1090, Acc: 70.12%, F1: 0.6936
# Val   - Loss: 1.3753, Acc: 61.24%, F1: 0.5731
# Learning Rate: 9.57e-05
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260127_080102-0ot6hg82/files/best_model.pth
# ✅ New best model saved with F1: 0.5731
#
# ============================================================
# Epoch 5/30
# ============================================================
# Epoch 5 Training: 100%|██████████| 1126/1126 [03:31<00:00,  5.34it/s, Loss=1.0700, Acc=72.37%, LR=9.57e-05]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.44it/s, Loss=1.3804, Acc=59.65%]
# Epoch 5 Summary:
# Train - Loss: 1.0700, Acc: 72.37%, F1: 0.7174
# Val   - Loss: 1.3804, Acc: 59.65%, F1: 0.5350
# Learning Rate: 9.34e-05
#
# ============================================================
# Epoch 6/30
# ============================================================
# Epoch 6 Training: 100%|██████████| 1126/1126 [03:31<00:00,  5.33it/s, Loss=1.0276, Acc=74.44%, LR=9.34e-05]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.45it/s, Loss=1.3739, Acc=60.45%]
# Epoch 6 Summary:
# Train - Loss: 1.0276, Acc: 74.44%, F1: 0.7379
# Val   - Loss: 1.3739, Acc: 60.45%, F1: 0.5683
# Learning Rate: 9.05e-05
#
# ============================================================
# Epoch 7/30
# ============================================================
# Epoch 7 Training: 100%|██████████| 1126/1126 [03:31<00:00,  5.33it/s, Loss=0.9985, Acc=75.65%, LR=9.05e-05]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.45it/s, Loss=1.3720, Acc=61.08%]
# Epoch 7 Summary:
# Train - Loss: 0.9985, Acc: 75.65%, F1: 0.7511
# Val   - Loss: 1.3720, Acc: 61.08%, F1: 0.5618
# Learning Rate: 8.73e-05
#
# ============================================================
# Epoch 8/30
# ============================================================
# Epoch 8 Training: 100%|██████████| 1126/1126 [03:31<00:00,  5.34it/s, Loss=0.9750, Acc=77.26%, LR=8.73e-05]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.45it/s, Loss=1.3405, Acc=63.16%]
# Epoch 8 Summary:
# Train - Loss: 0.9750, Acc: 77.26%, F1: 0.7676
# Val   - Loss: 1.3405, Acc: 63.16%, F1: 0.6031
# Learning Rate: 8.36e-05
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260127_080102-0ot6hg82/files/best_model.pth
# ✅ New best model saved with F1: 0.6031
#
# ============================================================
# Epoch 9/30
# ============================================================
# Epoch 9 Training: 100%|██████████| 1126/1126 [03:32<00:00,  5.30it/s, Loss=0.9571, Acc=78.09%, LR=8.36e-05]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.44it/s, Loss=1.3898, Acc=61.88%]
# Epoch 9 Summary:
# Train - Loss: 0.9571, Acc: 78.09%, F1: 0.7758
# Val   - Loss: 1.3898, Acc: 61.88%, F1: 0.5654
# Learning Rate: 7.96e-05
#
# ============================================================
# Epoch 10/30
# ============================================================
# Epoch 10 Training: 100%|██████████| 1126/1126 [03:31<00:00,  5.34it/s, Loss=0.9404, Acc=78.81%, LR=7.96e-05]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.45it/s, Loss=1.3674, Acc=60.29%]
# Epoch 10 Summary:
# Train - Loss: 0.9404, Acc: 78.81%, F1: 0.7839
# Val   - Loss: 1.3674, Acc: 60.29%, F1: 0.5691
# Learning Rate: 7.52e-05
#
# ============================================================
# Epoch 11/30
# ============================================================
# Epoch 11 Training: 100%|██████████| 1126/1126 [03:30<00:00,  5.34it/s, Loss=0.9162, Acc=80.19%, LR=7.52e-05]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.45it/s, Loss=1.3981, Acc=63.16%]
# Epoch 11 Summary:
# Train - Loss: 0.9162, Acc: 80.19%, F1: 0.7984
# Val   - Loss: 1.3981, Acc: 63.16%, F1: 0.6002
# Learning Rate: 7.06e-05
#
# ============================================================
# Epoch 12/30
# ============================================================
# Epoch 12 Training: 100%|██████████| 1126/1126 [03:31<00:00,  5.34it/s, Loss=0.8966, Acc=80.63%, LR=7.06e-05]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.44it/s, Loss=1.3958, Acc=61.56%]
# Epoch 12 Summary:
# Train - Loss: 0.8966, Acc: 80.63%, F1: 0.8027
# Val   - Loss: 1.3958, Acc: 61.56%, F1: 0.5939
# Learning Rate: 6.58e-05
#
# ============================================================
# Epoch 13/30
# ============================================================
# Epoch 13 Training: 100%|██████████| 1126/1126 [03:30<00:00,  5.34it/s, Loss=0.8937, Acc=80.94%, LR=6.58e-05]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.45it/s, Loss=1.3423, Acc=64.11%]
# Epoch 13 Summary:
# Train - Loss: 0.8937, Acc: 80.94%, F1: 0.8054
# Val   - Loss: 1.3423, Acc: 64.11%, F1: 0.6141
# Learning Rate: 6.08e-05
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260127_080102-0ot6hg82/files/best_model.pth
# ✅ New best model saved with F1: 0.6141
#
# ============================================================
# Epoch 14/30
# ============================================================
# Epoch 14 Training: 100%|██████████| 1126/1126 [03:30<00:00,  5.34it/s, Loss=0.8781, Acc=81.95%, LR=6.08e-05]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.45it/s, Loss=1.3442, Acc=65.39%]
# Epoch 14 Summary:
# Train - Loss: 0.8781, Acc: 81.95%, F1: 0.8162
# Val   - Loss: 1.3442, Acc: 65.39%, F1: 0.6301
# Learning Rate: 5.57e-05
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260127_080102-0ot6hg82/files/best_model.pth
# ✅ New best model saved with F1: 0.6301
#
# ============================================================
# Epoch 15/30
# ============================================================
# Epoch 15 Training: 100%|██████████| 1126/1126 [03:30<00:00,  5.34it/s, Loss=0.8626, Acc=82.54%, LR=5.57e-05]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.45it/s, Loss=1.3557, Acc=63.00%]
# Epoch 15 Summary:
# Train - Loss: 0.8626, Acc: 82.54%, F1: 0.8222
# Val   - Loss: 1.3557, Acc: 63.00%, F1: 0.6095
# Learning Rate: 5.05e-05
#
# ============================================================
# Epoch 16/30
# ============================================================
# Epoch 16 Training: 100%|██████████| 1126/1126 [03:30<00:00,  5.34it/s, Loss=0.8569, Acc=83.09%, LR=5.05e-05]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.44it/s, Loss=1.3725, Acc=64.91%]
# Epoch 16 Summary:
# Train - Loss: 0.8569, Acc: 83.09%, F1: 0.8276
# Val   - Loss: 1.3725, Acc: 64.91%, F1: 0.6242
# Learning Rate: 4.53e-05
#
# ============================================================
# Epoch 17/30
# ============================================================
# Epoch 17 Training: 100%|██████████| 1126/1126 [03:31<00:00,  5.33it/s, Loss=0.8437, Acc=83.60%, LR=4.53e-05]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.44it/s, Loss=1.3391, Acc=65.23%]
# Epoch 17 Summary:
# Train - Loss: 0.8437, Acc: 83.60%, F1: 0.8333
# Val   - Loss: 1.3391, Acc: 65.23%, F1: 0.6277
# Learning Rate: 4.02e-05
#
# ============================================================
# Epoch 18/30
# ============================================================
# Epoch 18 Training: 100%|██████████| 1126/1126 [03:31<00:00,  5.33it/s, Loss=0.8394, Acc=83.86%, LR=4.02e-05]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.44it/s, Loss=1.3291, Acc=63.64%]
# Epoch 18 Summary:
# Train - Loss: 0.8394, Acc: 83.86%, F1: 0.8361
# Val   - Loss: 1.3291, Acc: 63.64%, F1: 0.6178
# Learning Rate: 3.52e-05
#
# ============================================================
# Epoch 19/30
# ============================================================
# Epoch 19 Training: 100%|██████████| 1126/1126 [03:31<00:00,  5.32it/s, Loss=0.8286, Acc=84.71%, LR=3.52e-05]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.45it/s, Loss=1.3583, Acc=64.59%]
# Epoch 19 Summary:
# Train - Loss: 0.8286, Acc: 84.71%, F1: 0.8450
# Val   - Loss: 1.3583, Acc: 64.59%, F1: 0.6254
# Learning Rate: 3.04e-05
#
# ============================================================
# Epoch 20/30
# ============================================================
# Epoch 20 Training: 100%|██████████| 1126/1126 [03:30<00:00,  5.34it/s, Loss=0.8249, Acc=84.48%, LR=3.04e-05]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.45it/s, Loss=1.3334, Acc=64.59%]
# Epoch 20 Summary:
# Train - Loss: 0.8249, Acc: 84.48%, F1: 0.8421
# Val   - Loss: 1.3334, Acc: 64.59%, F1: 0.6232
# Learning Rate: 2.58e-05
#
# ============================================================
# Epoch 21/30
# ============================================================
# Epoch 21 Training: 100%|██████████| 1126/1126 [03:31<00:00,  5.33it/s, Loss=0.8184, Acc=85.12%, LR=2.58e-05]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.45it/s, Loss=1.3640, Acc=64.59%]
# Epoch 21 Summary:
# Train - Loss: 0.8184, Acc: 85.12%, F1: 0.8489
# Val   - Loss: 1.3640, Acc: 64.59%, F1: 0.6223
# Learning Rate: 2.14e-05
#
# ============================================================
# Epoch 22/30
# ============================================================
# Epoch 22 Training: 100%|██████████| 1126/1126 [03:33<00:00,  5.28it/s, Loss=0.8159, Acc=85.16%, LR=2.14e-05]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.45it/s, Loss=1.3649, Acc=63.80%]
# Epoch 22 Summary:
# Train - Loss: 0.8159, Acc: 85.16%, F1: 0.8493
# Val   - Loss: 1.3649, Acc: 63.80%, F1: 0.6188
# Learning Rate: 1.74e-05
#
# ============================================================
# Epoch 23/30
# ============================================================
# Epoch 23 Training: 100%|██████████| 1126/1126 [03:32<00:00,  5.30it/s, Loss=0.8103, Acc=85.37%, LR=1.74e-05]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.44it/s, Loss=1.3569, Acc=64.11%]
# Epoch 23 Summary:
# Train - Loss: 0.8103, Acc: 85.37%, F1: 0.8509
# Val   - Loss: 1.3569, Acc: 64.11%, F1: 0.6223
# Learning Rate: 1.37e-05
#
# ============================================================
# Epoch 24/30
# ============================================================
# Epoch 24 Training: 100%|██████████| 1126/1126 [03:31<00:00,  5.34it/s, Loss=0.8052, Acc=85.73%, LR=1.37e-05]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.44it/s, Loss=1.3706, Acc=64.27%]
# Epoch 24 Summary:
# Train - Loss: 0.8052, Acc: 85.73%, F1: 0.8553
# Val   - Loss: 1.3706, Acc: 64.27%, F1: 0.6205
# Learning Rate: 1.05e-05
#
# ============================================================
# Epoch 25/30
# ============================================================
# Epoch 25 Training: 100%|██████████| 1126/1126 [03:31<00:00,  5.34it/s, Loss=0.8041, Acc=85.51%, LR=1.05e-05]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.44it/s, Loss=1.3707, Acc=64.75%]
# Epoch 25 Summary:
# Train - Loss: 0.8041, Acc: 85.51%, F1: 0.8528
# Val   - Loss: 1.3707, Acc: 64.75%, F1: 0.6240
# Learning Rate: 7.63e-06
#
# ============================================================
# Epoch 26/30
# ============================================================
# Epoch 26 Training: 100%|██████████| 1126/1126 [03:31<00:00,  5.33it/s, Loss=0.7991, Acc=86.20%, LR=7.63e-06]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.44it/s, Loss=1.3506, Acc=64.11%]
# Epoch 26 Summary:
# Train - Loss: 0.7991, Acc: 86.20%, F1: 0.8598
# Val   - Loss: 1.3506, Acc: 64.11%, F1: 0.6213
# Learning Rate: 5.28e-06
#
# ============================================================
# Epoch 27/30
# ============================================================
# Epoch 27 Training: 100%|██████████| 1126/1126 [03:30<00:00,  5.34it/s, Loss=0.7971, Acc=86.18%, LR=5.28e-06]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.44it/s, Loss=1.3544, Acc=64.75%]
# Epoch 27 Summary:
# Train - Loss: 0.7971, Acc: 86.18%, F1: 0.8596
# Val   - Loss: 1.3544, Acc: 64.75%, F1: 0.6257
# Learning Rate: 3.42e-06
#
# ============================================================
# Epoch 28/30
# ============================================================
# Epoch 28 Training: 100%|██████████| 1126/1126 [03:31<00:00,  5.32it/s, Loss=0.7947, Acc=86.07%, LR=3.42e-06]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.45it/s, Loss=1.3556, Acc=64.59%]
# Epoch 28 Summary:
# Train - Loss: 0.7947, Acc: 86.07%, F1: 0.8587
# Val   - Loss: 1.3556, Acc: 64.59%, F1: 0.6228
# Learning Rate: 2.08e-06
#
# ============================================================
# Epoch 29/30
# ============================================================
# Epoch 29 Training: 100%|██████████| 1126/1126 [03:30<00:00,  5.34it/s, Loss=0.7969, Acc=86.08%, LR=2.08e-06]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.45it/s, Loss=1.3456, Acc=64.27%]
# Epoch 29 Summary:
# Train - Loss: 0.7969, Acc: 86.08%, F1: 0.8588
# Val   - Loss: 1.3456, Acc: 64.27%, F1: 0.6208
# Learning Rate: 1.27e-06
#
# ============================================================
# Epoch 30/30
# ============================================================
# Epoch 30 Training: 100%|██████████| 1126/1126 [03:33<00:00,  5.27it/s, Loss=0.7948, Acc=86.38%, LR=1.27e-06]
# Validation: 100%|██████████| 40/40 [00:11<00:00,  3.45it/s, Loss=1.3460, Acc=64.43%]
# Epoch 30 Summary:
# Train - Loss: 0.7948, Acc: 86.38%, F1: 0.8616
# Val   - Loss: 1.3460, Acc: 64.43%, F1: 0.6218
# Learning Rate: 1.00e-06

# %%
# cell 6: Test
test_loss, test_acc, test_f1 = trainer.test()
print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}, Test F1: {test_f1:.4f}")
# Out:
# ============================================================
# Testing Model
# ============================================================
# Model loaded from /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260127_080102-0ot6hg82/files/best_model.pth
# Testing: 100%|██████████| 40/40 [00:11<00:00,  3.45it/s, Loss=1.3352, Acc=62.68%]
# 📊 Test Results:
# Test Loss: 1.3352
# Test Accuracy: 62.68%
# Test Weighted F1 Score: 0.5925
#
# 📋 Detailed Classification Report:
#               precision    recall  f1-score   support
#
#       normal       0.61      0.89      0.73       282
#     diabetes       0.72      0.37      0.49       160
#     glaucoma       0.59      0.36      0.44        28
#     cataract       0.65      0.89      0.75        27
#       ageing       0.77      0.38      0.51        26
# hypertension       0.00      0.00      0.00        13
#       myopia       0.83      0.87      0.85        23
#        other       0.47      0.26      0.34        68
#
#     accuracy                           0.63       627
#    macro avg       0.58      0.50      0.51       627
# weighted avg       0.63      0.63      0.59       627
#
# Test Loss: 1.3352, Test Acc: 62.6794, Test F1: 0.5925

# %%
import os
final_model_path = os.path.join('ODIR-2019/results/', 'efficientnet-b0_augmented_512.pth')
trainer.save_model(final_model_path)
# Out:
# Model saved to ODIR-2019/results/efficientnet-b0_augmented_512.pth

# %%
wandb.finish()
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>learning_rate</td><td>█████▇▇▇▇▆▆▆▅▅▅▄▄▃▃▃▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>test_acc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>train_acc</td><td>▁▃▄▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇████████████</td></tr><tr><td>train_f1</td><td>▁▃▄▅▅▆▆▆▆▆▇▇▇▇▇▇▇█████████████</td></tr><tr><td>train_loss</td><td>█▆▅▄▄▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▃▅▆▅▆▆▇▆▆▇▆▇█▇██▇███▇▇▇█▇██▇█</td></tr><tr><td>val_f1</td><td>▁▃▃▅▃▅▅▇▅▅▆▆▇█▇██▇███▇████████</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>30</td></tr><tr><td>learning_rate</td><td>0.0</td></tr><tr><td>test_acc</td><td>62.67943</td></tr><tr><td>test_f1</td><td>0.59252</td></tr><tr><td>test_loss</td><td>1.33515</td></tr><tr><td>train_acc</td><td>86.37877</td></tr><tr><td>train_f1</td><td>0.86156</td></tr><tr><td>train_loss</td><td>0.79475</td></tr><tr><td>val_acc</td><td>64.43381</td></tr><tr><td>val_f1</td><td>0.6218</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">efficientnet-b0_augmented_512</strong> at: <a href='https://wandb.ai/samalo/odir-2019/runs/0ot6hg82' target="_blank">https://wandb.ai/samalo/odir-2019/runs/0ot6hg82</a><br> View project at: <a href='https://wandb.ai/samalo/odir-2019' target="_blank">https://wandb.ai/samalo/odir-2019</a><br>Synced 5 W&B file(s), 9 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260127_080102-0ot6hg82/logs</code>
