# %% [markdown]
# # EfficientNet-B4 Processed Merged Gamma Binary Diabetes
#
#
# Here we run experiment with ODIR-2019 Gamma enhanced Processed images and additional training images from Ocular Diseases DataSet
# except for Normal which we leave the ODIR-2019 original images as it is
#
# Here we test whether binary classifier has higher f1 for Diabetes

# %%
data_dir = './ODIR-2019/YOLO/processed_512g_merged'  # Your dataset path
model_name = 'efficientnet-b4'
saved_model_name = 'efficientnet-b4-odir-2019-pmgb-diabetes.pth'
wandb_project = "odir-2019-binary-classification"
wandb_run_name = 'efficientnet-b4_pmgb-diabetes'
binary_class = 'diabetes'

# %% [markdown]
# The following codes are generic or the same across experiments

# %%
# %%capture
# !pip install efficientnet-pytorch wandb torch torchvision scikit-learn seaborn tqdm

# %%
import sys
sys.path.append('.')

from efficient_net_v2 import EfficientNetTrainer

# %%
from util import get_train_device

device_for_training = get_train_device()
# Out:
# Using NVIDIA GPU (CUDA)

# %%
import wandb
config = {
    'data_dir': data_dir,
    'model_name': model_name,
    'image_size': 512,
    'batch_size': 16,  # Smaller for Jupyter
    'epochs': 30,
    'lr': 0.001,
    'weight_decay': 1e-4,
    'optimizer': 'adamw',
    'scheduler': 'cosine',
    'fine_tune': True,
    'unfreeze_blocks': 3,
    'label_smoothing': 0.1,
    'num_workers': 2,  # Lower for Jupyter
    'use_amp': True,
    'seed': 42,
    'binary_class': binary_class
}
wandb.init(project=wandb_project, name=wandb_run_name, config=config)
trainer = EfficientNetTrainer(config)
trainer.train()
# Out:
# wandb: Currently logged in as: raymond-samalo (samalo) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260208_163802-0wvvzh3a</code>
# Syncing run <strong><a href='https://wandb.ai/samalo/odir-2019-binary-classification/runs/0wvvzh3a' target="_blank">efficientnet-b4_pmgb-diabetes</a></strong> to <a href='https://wandb.ai/samalo/odir-2019-binary-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/samalo/odir-2019-binary-classification' target="_blank">https://wandb.ai/samalo/odir-2019-binary-classification</a>
#  View run at <a href='https://wandb.ai/samalo/odir-2019-binary-classification/runs/0wvvzh3a' target="_blank">https://wandb.ai/samalo/odir-2019-binary-classification/runs/0wvvzh3a</a>
# Using device: cuda
#
# ==================================================
# 🚀 BINARY CLASSIFICATION MODE: diabetes vs all other classes
# ==================================================
# Loading efficientnet-b4 with 2 classes...
# Loaded pretrained weights for efficientnet-b4
# Loading datasets from ./ODIR-2019/YOLO/processed_512g_merged...
# ⚠️  Binary classification mode: diabetes vs all other classes
# Found 9478 images in train split
#
# Binary class distribution in train split:
#   diabetes: 2790 samples (29.4%)
#   not_diabetes: 6688 samples (70.6%)
# ⚠️  Binary classification mode: diabetes vs all other classes
# Found 627 images in val split
#
# Binary class distribution in val split:
#   diabetes: 160 samples (25.5%)
#   not_diabetes: 467 samples (74.5%)
# ⚠️  Binary classification mode: diabetes vs all other classes
# Found 627 images in test split
#
# Binary class distribution in test split:
#   diabetes: 160 samples (25.5%)
#   not_diabetes: 467 samples (74.5%)
#
# 📊 Dataset Statistics:
#    Train samples: 9478
#    Val samples:   627
#    Test samples:  627
#    Image size:    512
#    Batch size:    16
#    Mode:          Binary (diabetes vs all)
# Class balance - Positive: 2790, Negative: 6688
# Positive weight for BCE loss: 2.3971
# Using weighted BCE loss with pos_weight: 2.3971
#
# ============================================================
# Epoch 1/30
# ============================================================
# Epoch 1 Training: 100%|██████████| 592/592 [04:30<00:00,  2.19it/s, Loss=0.4286, Acc=81.44%, LR=1.00e-04]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.4581, Acc=78.95%]
# 📊 Epoch 1 Summary:
# Train - Loss: 0.4286, Acc: 81.44%, F1: 0.6282
# Val   - Loss: 0.4581, Acc: 78.95%, F1: 0.4634
# Learning Rate: 9.97e-05
#   Time - Epoch: 300.2s, Inference: 16.1ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260208_163802-0wvvzh3a/files/best_model.pth
# ✅ New best model saved with F1: 0.4634
#
# ============================================================
# Epoch 2/30
# ============================================================
# Epoch 2 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.3699, Acc=84.34%, LR=9.97e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.4288, Acc=80.38%]
# 📊 Epoch 2 Summary:
# Train - Loss: 0.3699, Acc: 84.34%, F1: 0.7012
# Val   - Loss: 0.4288, Acc: 80.38%, F1: 0.5886
# Learning Rate: 9.89e-05
#   Time - Epoch: 295.2s, Inference: 10.5ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260208_163802-0wvvzh3a/files/best_model.pth
# ✅ New best model saved with F1: 0.5886
#
# ============================================================
# Epoch 3/30
# ============================================================
# Epoch 3 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.3482, Acc=85.71%, LR=9.89e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.4140, Acc=81.82%]
# 📊 Epoch 3 Summary:
# Train - Loss: 0.3482, Acc: 85.71%, F1: 0.7247
# Val   - Loss: 0.4140, Acc: 81.82%, F1: 0.5043
# Learning Rate: 9.76e-05
#   Time - Epoch: 295.1s, Inference: 9.7ms
#
# ============================================================
# Epoch 4/30
# ============================================================
# Epoch 4 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.3325, Acc=86.21%, LR=9.76e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.4319, Acc=80.54%]
# 📊 Epoch 4 Summary:
# Train - Loss: 0.3325, Acc: 86.21%, F1: 0.7421
# Val   - Loss: 0.4319, Acc: 80.54%, F1: 0.4245
# Learning Rate: 9.57e-05
#   Time - Epoch: 295.1s, Inference: 9.4ms
#
# ============================================================
# Epoch 5/30
# ============================================================
# Epoch 5 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.3270, Acc=86.68%, LR=9.57e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.3879, Acc=83.73%]
# 📊 Epoch 5 Summary:
# Train - Loss: 0.3270, Acc: 86.68%, F1: 0.7501
# Val   - Loss: 0.3879, Acc: 83.73%, F1: 0.5820
# Learning Rate: 9.34e-05
#   Time - Epoch: 295.0s, Inference: 9.6ms
#
# ============================================================
# Epoch 6/30
# ============================================================
# Epoch 6 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.3057, Acc=87.64%, LR=9.34e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.3940, Acc=82.93%]
# 📊 Epoch 6 Summary:
# Train - Loss: 0.3057, Acc: 87.64%, F1: 0.7692
# Val   - Loss: 0.3940, Acc: 82.93%, F1: 0.6298
# Learning Rate: 9.05e-05
#   Time - Epoch: 295.1s, Inference: 9.7ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260208_163802-0wvvzh3a/files/best_model.pth
# ✅ New best model saved with F1: 0.6298
#
# ============================================================
# Epoch 7/30
# ============================================================
# Epoch 7 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.3012, Acc=87.70%, LR=9.05e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.4358, Acc=83.09%]
# 📊 Epoch 7 Summary:
# Train - Loss: 0.3012, Acc: 87.70%, F1: 0.7697
# Val   - Loss: 0.4358, Acc: 83.09%, F1: 0.5391
# Learning Rate: 8.73e-05
#   Time - Epoch: 295.7s, Inference: 9.9ms
#
# ============================================================
# Epoch 8/30
# ============================================================
# Epoch 8 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.2943, Acc=87.87%, LR=8.73e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.3947, Acc=84.21%]
# 📊 Epoch 8 Summary:
# Train - Loss: 0.2943, Acc: 87.87%, F1: 0.7755
# Val   - Loss: 0.3947, Acc: 84.21%, F1: 0.6264
# Learning Rate: 8.36e-05
#   Time - Epoch: 295.6s, Inference: 9.6ms
#
# ============================================================
# Epoch 9/30
# ============================================================
# Epoch 9 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.2777, Acc=88.51%, LR=8.36e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.3800, Acc=84.85%]
# 📊 Epoch 9 Summary:
# Train - Loss: 0.2777, Acc: 88.51%, F1: 0.7874
# Val   - Loss: 0.3800, Acc: 84.85%, F1: 0.6520
# Learning Rate: 7.96e-05
#   Time - Epoch: 295.6s, Inference: 9.8ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260208_163802-0wvvzh3a/files/best_model.pth
# ✅ New best model saved with F1: 0.6520
#
# ============================================================
# Epoch 10/30
# ============================================================
# Epoch 10 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.2794, Acc=88.69%, LR=7.96e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.3816, Acc=84.85%]
# 📊 Epoch 10 Summary:
# Train - Loss: 0.2794, Acc: 88.69%, F1: 0.7922
# Val   - Loss: 0.3816, Acc: 84.85%, F1: 0.6185
# Learning Rate: 7.52e-05
#   Time - Epoch: 295.8s, Inference: 9.5ms
#
# ============================================================
# Epoch 11/30
# ============================================================
# Epoch 11 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.2638, Acc=88.95%, LR=7.52e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.4396, Acc=83.57%]
# 📊 Epoch 11 Summary:
# Train - Loss: 0.2638, Acc: 88.95%, F1: 0.7982
# Val   - Loss: 0.4396, Acc: 83.57%, F1: 0.5541
# Learning Rate: 7.06e-05
#   Time - Epoch: 295.7s, Inference: 9.8ms
#
# ============================================================
# Epoch 12/30
# ============================================================
# Epoch 12 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.2647, Acc=89.18%, LR=7.06e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.3829, Acc=84.69%]
# 📊 Epoch 12 Summary:
# Train - Loss: 0.2647, Acc: 89.18%, F1: 0.8001
# Val   - Loss: 0.3829, Acc: 84.69%, F1: 0.6190
# Learning Rate: 6.58e-05
#   Time - Epoch: 295.6s, Inference: 10.0ms
#
# ============================================================
# Epoch 13/30
# ============================================================
# Epoch 13 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.2526, Acc=90.02%, LR=6.58e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.3712, Acc=84.69%]
# 📊 Epoch 13 Summary:
# Train - Loss: 0.2526, Acc: 90.02%, F1: 0.8177
# Val   - Loss: 0.3712, Acc: 84.69%, F1: 0.6364
# Learning Rate: 6.08e-05
#   Time - Epoch: 295.6s, Inference: 9.5ms
#
# ============================================================
# Epoch 14/30
# ============================================================
# Epoch 14 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.2509, Acc=89.88%, LR=6.08e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.3818, Acc=85.17%]
# 📊 Epoch 14 Summary:
# Train - Loss: 0.2509, Acc: 89.88%, F1: 0.8150
# Val   - Loss: 0.3818, Acc: 85.17%, F1: 0.6381
# Learning Rate: 5.57e-05
#   Time - Epoch: 295.7s, Inference: 9.5ms
#
# ============================================================
# Epoch 15/30
# ============================================================
# Epoch 15 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.2404, Acc=90.39%, LR=5.57e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.3707, Acc=85.33%]
# 📊 Epoch 15 Summary:
# Train - Loss: 0.2404, Acc: 90.39%, F1: 0.8243
# Val   - Loss: 0.3707, Acc: 85.33%, F1: 0.6642
# Learning Rate: 5.05e-05
#   Time - Epoch: 295.5s, Inference: 9.8ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260208_163802-0wvvzh3a/files/best_model.pth
# ✅ New best model saved with F1: 0.6642
#
# ============================================================
# Epoch 16/30
# ============================================================
# Epoch 16 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.2327, Acc=90.53%, LR=5.05e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.4234, Acc=84.53%]
# 📊 Epoch 16 Summary:
# Train - Loss: 0.2327, Acc: 90.53%, F1: 0.8278
# Val   - Loss: 0.4234, Acc: 84.53%, F1: 0.6196
# Learning Rate: 4.53e-05
#   Time - Epoch: 295.7s, Inference: 9.4ms
#
# ============================================================
# Epoch 17/30
# ============================================================
# Epoch 17 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.2296, Acc=90.82%, LR=4.53e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.4058, Acc=85.49%]
# 📊 Epoch 17 Summary:
# Train - Loss: 0.2296, Acc: 90.82%, F1: 0.8325
# Val   - Loss: 0.4058, Acc: 85.49%, F1: 0.6566
# Learning Rate: 4.02e-05
#   Time - Epoch: 295.4s, Inference: 9.4ms
#
# ============================================================
# Epoch 18/30
# ============================================================
# Epoch 18 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.2350, Acc=90.60%, LR=4.02e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.4039, Acc=85.33%]
# 📊 Epoch 18 Summary:
# Train - Loss: 0.2350, Acc: 90.60%, F1: 0.8292
# Val   - Loss: 0.4039, Acc: 85.33%, F1: 0.6434
# Learning Rate: 3.52e-05
#   Time - Epoch: 295.5s, Inference: 9.7ms
#
# ============================================================
# Epoch 19/30
# ============================================================
# Epoch 19 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.2221, Acc=90.71%, LR=3.52e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.4639, Acc=84.37%]
# 📊 Epoch 19 Summary:
# Train - Loss: 0.2221, Acc: 90.71%, F1: 0.8308
# Val   - Loss: 0.4639, Acc: 84.37%, F1: 0.6111
# Learning Rate: 3.04e-05
#   Time - Epoch: 295.6s, Inference: 9.4ms
#
# ============================================================
# Epoch 20/30
# ============================================================
# Epoch 20 Training: 100%|██████████| 592/592 [04:26<00:00,  2.23it/s, Loss=0.2162, Acc=90.91%, LR=3.04e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.4101, Acc=85.01%]
# 📊 Epoch 20 Summary:
# Train - Loss: 0.2162, Acc: 90.91%, F1: 0.8363
# Val   - Loss: 0.4101, Acc: 85.01%, F1: 0.6594
# Learning Rate: 2.58e-05
#   Time - Epoch: 295.5s, Inference: 9.7ms
#
# ============================================================
# Epoch 21/30
# ============================================================
# Epoch 21 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.2216, Acc=91.06%, LR=2.58e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.4085, Acc=85.33%]
# 📊 Epoch 21 Summary:
# Train - Loss: 0.2216, Acc: 91.06%, F1: 0.8385
# Val   - Loss: 0.4085, Acc: 85.33%, F1: 0.6515
# Learning Rate: 2.14e-05
#   Time - Epoch: 295.7s, Inference: 9.7ms
#
# ============================================================
# Epoch 22/30
# ============================================================
# Epoch 22 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.2010, Acc=92.02%, LR=2.14e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.4059, Acc=85.33%]
# 📊 Epoch 22 Summary:
# Train - Loss: 0.2010, Acc: 92.02%, F1: 0.8563
# Val   - Loss: 0.4059, Acc: 85.33%, F1: 0.6618
# Learning Rate: 1.74e-05
#   Time - Epoch: 295.5s, Inference: 9.5ms
#
# ============================================================
# Epoch 23/30
# ============================================================
# Epoch 23 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.2096, Acc=91.66%, LR=1.74e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.4128, Acc=84.85%]
# 📊 Epoch 23 Summary:
# Train - Loss: 0.2096, Acc: 91.66%, F1: 0.8507
# Val   - Loss: 0.4128, Acc: 84.85%, F1: 0.6415
# Learning Rate: 1.37e-05
#   Time - Epoch: 295.7s, Inference: 9.7ms
#
# ============================================================
# Epoch 24/30
# ============================================================
# Epoch 24 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.2101, Acc=91.62%, LR=1.37e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.4148, Acc=84.85%]
# 📊 Epoch 24 Summary:
# Train - Loss: 0.2101, Acc: 91.62%, F1: 0.8493
# Val   - Loss: 0.4148, Acc: 84.85%, F1: 0.6442
# Learning Rate: 1.05e-05
#   Time - Epoch: 295.7s, Inference: 10.0ms
#
# ============================================================
# Epoch 25/30
# ============================================================
# Epoch 25 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.2093, Acc=91.52%, LR=1.05e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.4257, Acc=84.37%]
# 📊 Epoch 25 Summary:
# Train - Loss: 0.2093, Acc: 91.52%, F1: 0.8463
# Val   - Loss: 0.4257, Acc: 84.37%, F1: 0.6343
# Learning Rate: 7.63e-06
#   Time - Epoch: 295.7s, Inference: 9.4ms
#
# ============================================================
# Epoch 26/30
# ============================================================
# Epoch 26 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.2038, Acc=91.86%, LR=7.63e-06]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.4303, Acc=84.53%]
# 📊 Epoch 26 Summary:
# Train - Loss: 0.2038, Acc: 91.86%, F1: 0.8534
# Val   - Loss: 0.4303, Acc: 84.53%, F1: 0.6340
# Learning Rate: 5.28e-06
#   Time - Epoch: 295.8s, Inference: 9.9ms
#
# ============================================================
# Epoch 27/30
# ============================================================
# Epoch 27 Training: 100%|██████████| 592/592 [04:26<00:00,  2.23it/s, Loss=0.2040, Acc=91.65%, LR=5.28e-06]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.4430, Acc=84.85%]
# 📊 Epoch 27 Summary:
# Train - Loss: 0.2040, Acc: 91.65%, F1: 0.8502
# Val   - Loss: 0.4430, Acc: 84.85%, F1: 0.6360
# Learning Rate: 3.42e-06
#   Time - Epoch: 295.6s, Inference: 9.6ms
#
# ============================================================
# Epoch 28/30
# ============================================================
# Epoch 28 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.2038, Acc=91.97%, LR=3.42e-06]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.4432, Acc=84.69%]
# 📊 Epoch 28 Summary:
# Train - Loss: 0.2038, Acc: 91.97%, F1: 0.8554
# Val   - Loss: 0.4432, Acc: 84.69%, F1: 0.6308
# Learning Rate: 2.08e-06
#   Time - Epoch: 295.5s, Inference: 9.4ms
#
# ============================================================
# Epoch 29/30
# ============================================================
# Epoch 29 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.1991, Acc=91.92%, LR=2.08e-06]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.4436, Acc=84.85%]
# 📊 Epoch 29 Summary:
# Train - Loss: 0.1991, Acc: 91.92%, F1: 0.8548
# Val   - Loss: 0.4436, Acc: 84.85%, F1: 0.6388
# Learning Rate: 1.27e-06
#   Time - Epoch: 295.6s, Inference: 9.5ms
#
# ============================================================
# Epoch 30/30
# ============================================================
# Epoch 30 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.2005, Acc=91.74%, LR=1.27e-06]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.4390, Acc=84.69%]
# 📊 Epoch 30 Summary:
# Train - Loss: 0.2005, Acc: 91.74%, F1: 0.8503
# Val   - Loss: 0.4390, Acc: 84.69%, F1: 0.6364
# Learning Rate: 1.00e-06
#   Time - Epoch: 295.6s, Inference: 9.6ms
#
# 🎉 Training completed!
# 📈 Best validation F1: 0.6642
# ⏱️  Average epoch time: 295.7s
# ⚡ Average inference time: 9.9ms

# %%
# cell 6: Test
test_loss, test_acc, test_f1 = trainer.test()
print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}, Test F1: {test_f1:.4f}")
# Out:
# ============================================================
# Testing Model
# ============================================================
# Model loaded from /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260208_163802-0wvvzh3a/files/best_model.pth
# Testing: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.4145, Acc=83.09%]
# 📊 Test Results:
# Test Loss: 0.4145
# Test Accuracy: 83.09%
# Test F1 Score: 0.6214
# Average Inference Time per Image: 9.84 ms
#
# 📋 Detailed Classification Report:
#               precision    recall  f1-score   support
#
# not_diabetes       0.86      0.93      0.89       467
#     diabetes       0.72      0.54      0.62       160
#
#     accuracy                           0.83       627
#    macro avg       0.79      0.74      0.76       627
# weighted avg       0.82      0.83      0.82       627
#
# Test Loss: 0.4145, Test Acc: 83.0941, Test F1: 0.6214

# %%
import os
final_model_path = os.path.join('ODIR-2019/results/', saved_model_name)
trainer.save_model(final_model_path)
# Out:
# Model saved to ODIR-2019/results/efficientnet-b4-odir-2019-pmgb-diabetes.pth

# %%
wandb.finish()
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>learning_rate</td><td>█████▇▇▇▇▆▆▆▅▅▅▄▄▃▃▃▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>test_acc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>train_acc</td><td>▁▃▄▄▄▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇█████████</td></tr><tr><td>train_f1</td><td>▁▃▄▄▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇█████████</td></tr><tr><td>train_loss</td><td>█▆▆▅▅▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▃▄▃▆▅▅▇▇▇▆▇▇██▇██▇▇██▇▇▇▇▇▇▇▇</td></tr><tr><td>val_f1</td><td>▂▆▃▁▆▇▄▇█▇▅▇▇▇█▇█▇▆███▇▇▇▇▇▇▇▇</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>30</td></tr><tr><td>learning_rate</td><td>0.0</td></tr><tr><td>test_acc</td><td>83.0941</td></tr><tr><td>test_f1</td><td>0.62143</td></tr><tr><td>test_loss</td><td>0.41448</td></tr><tr><td>train_acc</td><td>91.74409</td></tr><tr><td>train_f1</td><td>0.85031</td></tr><tr><td>train_loss</td><td>0.20048</td></tr><tr><td>val_acc</td><td>84.689</td></tr><tr><td>val_f1</td><td>0.63636</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">efficientnet-b4_pmgb-diabetes</strong> at: <a href='https://wandb.ai/samalo/odir-2019-binary-classification/runs/0wvvzh3a' target="_blank">https://wandb.ai/samalo/odir-2019-binary-classification/runs/0wvvzh3a</a><br> View project at: <a href='https://wandb.ai/samalo/odir-2019-binary-classification' target="_blank">https://wandb.ai/samalo/odir-2019-binary-classification</a><br>Synced 5 W&B file(s), 9 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260208_163802-0wvvzh3a/logs</code>
