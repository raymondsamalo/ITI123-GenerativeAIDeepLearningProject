# %% [markdown]
# # EfficientNet-B4 Processed Merged Gamma Binary
#
#
# Here we run experiment with ODIR-2019 Gamma enhanced Processed images and additional training images from Ocular Diseases DataSet
# except for Normal which we leave the ODIR-2019 original images as it is
#
# Here we test whether binary classifier has higher f1 for normal

# %%
data_dir = './ODIR-2019/YOLO/processed_512g_merged'  # Your dataset path
model_name = 'efficientnet-b4'
saved_model_name = 'efficientnet-b4-odir-2019-pmgb-normal.pth'
wandb_project = "odir-2019-binary-classification"
wandb_run_name = 'efficientnet-b4_pmgb'

# %% [markdown]
# The following codes are generic or the same across experiments

# %%
# %%capture
# !pip install efficientnet-pytorch wandb torch torchvision scikit-learn seaborn tqdm

# %%
import sys
sys.path.append('.')

from efficient_net_v2 import EfficientNetTrainer

# %%
from util import get_train_device

device_for_training = get_train_device()
# Out:
# Using NVIDIA GPU (CUDA)

# %%
import wandb
config = {
    'data_dir': data_dir,
    'model_name': model_name,
    'image_size': 512,
    'batch_size': 16,  # Smaller for Jupyter
    'epochs': 30,
    'lr': 0.001,
    'weight_decay': 1e-4,
    'optimizer': 'adamw',
    'scheduler': 'cosine',
    'fine_tune': True,
    'unfreeze_blocks': 3,
    'label_smoothing': 0.1,
    'num_workers': 2,  # Lower for Jupyter
    'use_amp': True,
    'seed': 42,
    'binary_class':'normal'
}
wandb.init(project=wandb_project, name=wandb_run_name, config=config)
trainer = EfficientNetTrainer(config)
trainer.train()
# Out:
# wandb: Currently logged in as: raymond-samalo (samalo) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260208_134820-20mu7r8z</code>
# Syncing run <strong><a href='https://wandb.ai/samalo/odir-2019-binary-classification/runs/20mu7r8z' target="_blank">efficientnet-b4_pmgb</a></strong> to <a href='https://wandb.ai/samalo/odir-2019-binary-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/samalo/odir-2019-binary-classification' target="_blank">https://wandb.ai/samalo/odir-2019-binary-classification</a>
#  View run at <a href='https://wandb.ai/samalo/odir-2019-binary-classification/runs/20mu7r8z' target="_blank">https://wandb.ai/samalo/odir-2019-binary-classification/runs/20mu7r8z</a>
# Using device: cuda
#
# ==================================================
# 🚀 BINARY CLASSIFICATION MODE: normal vs all other classes
# ==================================================
# Loading efficientnet-b4 with 2 classes...
# Loaded pretrained weights for efficientnet-b4
# Loading datasets from ./ODIR-2019/YOLO/processed_512g_merged...
# ⚠️  Binary classification mode: normal vs all other classes
# Found 9478 images in train split
#
# Binary class distribution in train split:
#   normal: 2252 samples (23.8%)
#   not_normal: 7226 samples (76.2%)
# ⚠️  Binary classification mode: normal vs all other classes
# Found 627 images in val split
#
# Binary class distribution in val split:
#   normal: 282 samples (45.0%)
#   not_normal: 345 samples (55.0%)
# ⚠️  Binary classification mode: normal vs all other classes
# Found 627 images in test split
#
# Binary class distribution in test split:
#   normal: 282 samples (45.0%)
#   not_normal: 345 samples (55.0%)
#
# 📊 Dataset Statistics:
#    Train samples: 9478
#    Val samples:   627
#    Test samples:  627
#    Image size:    512
#    Batch size:    16
#    Mode:          Binary (normal vs all)
# Class balance - Positive: 2252, Negative: 7226
# Positive weight for BCE loss: 3.2087
# Using weighted BCE loss with pos_weight: 3.2087
#
# ============================================================
# Epoch 1/30
# ============================================================
# Epoch 1 Training: 100%|██████████| 592/592 [04:29<00:00,  2.20it/s, Loss=0.4139, Acc=78.26%, LR=1.00e-04]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=0.7265, Acc=62.68%]
# 📊 Epoch 1 Summary:
# Train - Loss: 0.4139, Acc: 78.26%, F1: 0.4797
# Val   - Loss: 0.7265, Acc: 62.68%, F1: 0.6667
# Learning Rate: 9.97e-05
#   Time - Epoch: 298.6s, Inference: 15.9ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260208_134820-20mu7r8z/files/best_model.pth
# ✅ New best model saved with F1: 0.6667
#
# ============================================================
# Epoch 2/30
# ============================================================
# Epoch 2 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.3661, Acc=80.68%, LR=9.97e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.6063, Acc=67.62%]
# 📊 Epoch 2 Summary:
# Train - Loss: 0.3661, Acc: 80.68%, F1: 0.5641
# Val   - Loss: 0.6063, Acc: 67.62%, F1: 0.6721
# Learning Rate: 9.89e-05
#   Time - Epoch: 295.1s, Inference: 9.5ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260208_134820-20mu7r8z/files/best_model.pth
# ✅ New best model saved with F1: 0.6721
#
# ============================================================
# Epoch 3/30
# ============================================================
# Epoch 3 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.3458, Acc=82.16%, LR=9.89e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.6750, Acc=64.75%]
# 📊 Epoch 3 Summary:
# Train - Loss: 0.3458, Acc: 82.16%, F1: 0.6093
# Val   - Loss: 0.6750, Acc: 64.75%, F1: 0.7009
# Learning Rate: 9.76e-05
#   Time - Epoch: 295.0s, Inference: 10.4ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260208_134820-20mu7r8z/files/best_model.pth
# ✅ New best model saved with F1: 0.7009
#
# ============================================================
# Epoch 4/30
# ============================================================
# Epoch 4 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.3397, Acc=82.47%, LR=9.76e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.5637, Acc=70.02%]
# 📊 Epoch 4 Summary:
# Train - Loss: 0.3397, Acc: 82.47%, F1: 0.6140
# Val   - Loss: 0.5637, Acc: 70.02%, F1: 0.6948
# Learning Rate: 9.57e-05
#   Time - Epoch: 295.5s, Inference: 9.6ms
#
# ============================================================
# Epoch 5/30
# ============================================================
# Epoch 5 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.3193, Acc=84.13%, LR=9.57e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.6393, Acc=68.10%]
# 📊 Epoch 5 Summary:
# Train - Loss: 0.3193, Acc: 84.13%, F1: 0.6582
# Val   - Loss: 0.6393, Acc: 68.10%, F1: 0.7110
# Learning Rate: 9.34e-05
#   Time - Epoch: 295.3s, Inference: 11.1ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260208_134820-20mu7r8z/files/best_model.pth
# ✅ New best model saved with F1: 0.7110
#
# ============================================================
# Epoch 6/30
# ============================================================
# Epoch 6 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.3230, Acc=83.65%, LR=9.34e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.5636, Acc=71.61%]
# 📊 Epoch 6 Summary:
# Train - Loss: 0.3230, Acc: 83.65%, F1: 0.6485
# Val   - Loss: 0.5636, Acc: 71.61%, F1: 0.7351
# Learning Rate: 9.05e-05
#   Time - Epoch: 295.3s, Inference: 9.8ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260208_134820-20mu7r8z/files/best_model.pth
# ✅ New best model saved with F1: 0.7351
#
# ============================================================
# Epoch 7/30
# ============================================================
# Epoch 7 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.3083, Acc=85.06%, LR=9.05e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=0.5483, Acc=72.09%]
# 📊 Epoch 7 Summary:
# Train - Loss: 0.3083, Acc: 85.06%, F1: 0.6783
# Val   - Loss: 0.5483, Acc: 72.09%, F1: 0.7039
# Learning Rate: 8.73e-05
#   Time - Epoch: 295.8s, Inference: 9.3ms
#
# ============================================================
# Epoch 8/30
# ============================================================
# Epoch 8 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.2976, Acc=85.12%, LR=8.73e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.5543, Acc=73.05%]
# 📊 Epoch 8 Summary:
# Train - Loss: 0.2976, Acc: 85.12%, F1: 0.6844
# Val   - Loss: 0.5543, Acc: 73.05%, F1: 0.7388
# Learning Rate: 8.36e-05
#   Time - Epoch: 295.5s, Inference: 9.8ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260208_134820-20mu7r8z/files/best_model.pth
# ✅ New best model saved with F1: 0.7388
#
# ============================================================
# Epoch 9/30
# ============================================================
# Epoch 9 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.2986, Acc=85.20%, LR=8.36e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.5199, Acc=73.52%]
# 📊 Epoch 9 Summary:
# Train - Loss: 0.2986, Acc: 85.20%, F1: 0.6855
# Val   - Loss: 0.5199, Acc: 73.52%, F1: 0.7470
# Learning Rate: 7.96e-05
#   Time - Epoch: 295.2s, Inference: 10.0ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260208_134820-20mu7r8z/files/best_model.pth
# ✅ New best model saved with F1: 0.7470
#
# ============================================================
# Epoch 10/30
# ============================================================
# Epoch 10 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.2886, Acc=85.94%, LR=7.96e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.5242, Acc=73.05%]
# 📊 Epoch 10 Summary:
# Train - Loss: 0.2886, Acc: 85.94%, F1: 0.7015
# Val   - Loss: 0.5242, Acc: 73.05%, F1: 0.7019
# Learning Rate: 7.52e-05
#   Time - Epoch: 295.3s, Inference: 9.8ms
#
# ============================================================
# Epoch 11/30
# ============================================================
# Epoch 11 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.2902, Acc=85.54%, LR=7.52e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.5293, Acc=74.64%]
# 📊 Epoch 11 Summary:
# Train - Loss: 0.2902, Acc: 85.54%, F1: 0.6942
# Val   - Loss: 0.5293, Acc: 74.64%, F1: 0.7535
# Learning Rate: 7.06e-05
#   Time - Epoch: 295.3s, Inference: 9.2ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260208_134820-20mu7r8z/files/best_model.pth
# ✅ New best model saved with F1: 0.7535
#
# ============================================================
# Epoch 12/30
# ============================================================
# Epoch 12 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.2809, Acc=86.62%, LR=7.06e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.4971, Acc=75.28%]
# 📊 Epoch 12 Summary:
# Train - Loss: 0.2809, Acc: 86.62%, F1: 0.7128
# Val   - Loss: 0.4971, Acc: 75.28%, F1: 0.7488
# Learning Rate: 6.58e-05
#   Time - Epoch: 295.2s, Inference: 9.8ms
#
# ============================================================
# Epoch 13/30
# ============================================================
# Epoch 13 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.2697, Acc=86.94%, LR=6.58e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.4812, Acc=76.40%]
# 📊 Epoch 13 Summary:
# Train - Loss: 0.2697, Acc: 86.94%, F1: 0.7225
# Val   - Loss: 0.4812, Acc: 76.40%, F1: 0.7582
# Learning Rate: 6.08e-05
#   Time - Epoch: 295.0s, Inference: 9.8ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260208_134820-20mu7r8z/files/best_model.pth
# ✅ New best model saved with F1: 0.7582
#
# ============================================================
# Epoch 14/30
# ============================================================
# Epoch 14 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.2672, Acc=87.14%, LR=6.08e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.4799, Acc=75.76%]
# 📊 Epoch 14 Summary:
# Train - Loss: 0.2672, Acc: 87.14%, F1: 0.7282
# Val   - Loss: 0.4799, Acc: 75.76%, F1: 0.7524
# Learning Rate: 5.57e-05
#   Time - Epoch: 295.2s, Inference: 9.8ms
#
# ============================================================
# Epoch 15/30
# ============================================================
# Epoch 15 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.2614, Acc=87.25%, LR=5.57e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.5003, Acc=74.80%]
# 📊 Epoch 15 Summary:
# Train - Loss: 0.2614, Acc: 87.25%, F1: 0.7325
# Val   - Loss: 0.5003, Acc: 74.80%, F1: 0.7476
# Learning Rate: 5.05e-05
#   Time - Epoch: 295.0s, Inference: 9.3ms
#
# ============================================================
# Epoch 16/30
# ============================================================
# Epoch 16 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.2581, Acc=87.47%, LR=5.05e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.4987, Acc=74.96%]
# 📊 Epoch 16 Summary:
# Train - Loss: 0.2581, Acc: 87.47%, F1: 0.7346
# Val   - Loss: 0.4987, Acc: 74.96%, F1: 0.7379
# Learning Rate: 4.53e-05
#   Time - Epoch: 295.1s, Inference: 9.8ms
#
# ============================================================
# Epoch 17/30
# ============================================================
# Epoch 17 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.2586, Acc=87.57%, LR=4.53e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.5311, Acc=75.76%]
# 📊 Epoch 17 Summary:
# Train - Loss: 0.2586, Acc: 87.57%, F1: 0.7391
# Val   - Loss: 0.5311, Acc: 75.76%, F1: 0.7711
# Learning Rate: 4.02e-05
#   Time - Epoch: 295.2s, Inference: 9.6ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260208_134820-20mu7r8z/files/best_model.pth
# ✅ New best model saved with F1: 0.7711
#
# ============================================================
# Epoch 18/30
# ============================================================
# Epoch 18 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.2470, Acc=88.55%, LR=4.02e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.4904, Acc=76.08%]
# 📊 Epoch 18 Summary:
# Train - Loss: 0.2470, Acc: 88.55%, F1: 0.7583
# Val   - Loss: 0.4904, Acc: 76.08%, F1: 0.7541
# Learning Rate: 3.52e-05
#   Time - Epoch: 295.3s, Inference: 9.8ms
#
# ============================================================
# Epoch 19/30
# ============================================================
# Epoch 19 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.2379, Acc=89.03%, LR=3.52e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.5166, Acc=76.08%]
# 📊 Epoch 19 Summary:
# Train - Loss: 0.2379, Acc: 89.03%, F1: 0.7695
# Val   - Loss: 0.5166, Acc: 76.08%, F1: 0.7664
# Learning Rate: 3.04e-05
#   Time - Epoch: 295.5s, Inference: 9.8ms
#
# ============================================================
# Epoch 20/30
# ============================================================
# Epoch 20 Training: 100%|██████████| 592/592 [04:26<00:00,  2.23it/s, Loss=0.2445, Acc=88.58%, LR=3.04e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.4997, Acc=76.40%]
# 📊 Epoch 20 Summary:
# Train - Loss: 0.2445, Acc: 88.58%, F1: 0.7605
# Val   - Loss: 0.4997, Acc: 76.40%, F1: 0.7597
# Learning Rate: 2.58e-05
#   Time - Epoch: 295.5s, Inference: 9.4ms
#
# ============================================================
# Epoch 21/30
# ============================================================
# Epoch 21 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.2337, Acc=88.94%, LR=2.58e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.5224, Acc=75.76%]
# 📊 Epoch 21 Summary:
# Train - Loss: 0.2337, Acc: 88.94%, F1: 0.7690
# Val   - Loss: 0.5224, Acc: 75.76%, F1: 0.7556
# Learning Rate: 2.14e-05
#   Time - Epoch: 295.4s, Inference: 9.7ms
#
# ============================================================
# Epoch 22/30
# ============================================================
# Epoch 22 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.2363, Acc=88.71%, LR=2.14e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.5042, Acc=76.71%]
# 📊 Epoch 22 Summary:
# Train - Loss: 0.2363, Acc: 88.71%, F1: 0.7626
# Val   - Loss: 0.5042, Acc: 76.71%, F1: 0.7630
# Learning Rate: 1.74e-05
#   Time - Epoch: 295.4s, Inference: 9.5ms
#
# ============================================================
# Epoch 23/30
# ============================================================
# Epoch 23 Training: 100%|██████████| 592/592 [04:26<00:00,  2.23it/s, Loss=0.2321, Acc=89.19%, LR=1.74e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.5319, Acc=75.92%]
# 📊 Epoch 23 Summary:
# Train - Loss: 0.2321, Acc: 89.19%, F1: 0.7749
# Val   - Loss: 0.5319, Acc: 75.92%, F1: 0.7622
# Learning Rate: 1.37e-05
#   Time - Epoch: 295.5s, Inference: 10.4ms
#
# ============================================================
# Epoch 24/30
# ============================================================
# Epoch 24 Training: 100%|██████████| 592/592 [04:26<00:00,  2.23it/s, Loss=0.2332, Acc=89.03%, LR=1.37e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.5187, Acc=77.35%]
# 📊 Epoch 24 Summary:
# Train - Loss: 0.2332, Acc: 89.03%, F1: 0.7695
# Val   - Loss: 0.5187, Acc: 77.35%, F1: 0.7695
# Learning Rate: 1.05e-05
#   Time - Epoch: 295.5s, Inference: 9.3ms
#
# ============================================================
# Epoch 25/30
# ============================================================
# Epoch 25 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.2220, Acc=89.84%, LR=1.05e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.5381, Acc=76.40%]
# 📊 Epoch 25 Summary:
# Train - Loss: 0.2220, Acc: 89.84%, F1: 0.7898
# Val   - Loss: 0.5381, Acc: 76.40%, F1: 0.7628
# Learning Rate: 7.63e-06
#   Time - Epoch: 295.2s, Inference: 10.0ms
#
# ============================================================
# Epoch 26/30
# ============================================================
# Epoch 26 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.2279, Acc=89.61%, LR=7.63e-06]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.5326, Acc=76.40%]
# 📊 Epoch 26 Summary:
# Train - Loss: 0.2279, Acc: 89.61%, F1: 0.7807
# Val   - Loss: 0.5326, Acc: 76.40%, F1: 0.7636
# Learning Rate: 5.28e-06
#   Time - Epoch: 295.1s, Inference: 9.9ms
#
# ============================================================
# Epoch 27/30
# ============================================================
# Epoch 27 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.2233, Acc=89.89%, LR=5.28e-06]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.5357, Acc=76.24%]
# 📊 Epoch 27 Summary:
# Train - Loss: 0.2233, Acc: 89.89%, F1: 0.7884
# Val   - Loss: 0.5357, Acc: 76.24%, F1: 0.7624
# Learning Rate: 3.42e-06
#   Time - Epoch: 295.0s, Inference: 9.9ms
#
# ============================================================
# Epoch 28/30
# ============================================================
# Epoch 28 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.2219, Acc=89.89%, LR=3.42e-06]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.5329, Acc=76.40%]
# 📊 Epoch 28 Summary:
# Train - Loss: 0.2219, Acc: 89.89%, F1: 0.7883
# Val   - Loss: 0.5329, Acc: 76.40%, F1: 0.7658
# Learning Rate: 2.08e-06
#   Time - Epoch: 295.1s, Inference: 9.6ms
#
# ============================================================
# Epoch 29/30
# ============================================================
# Epoch 29 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.2195, Acc=89.79%, LR=2.08e-06]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.5313, Acc=77.19%]
# 📊 Epoch 29 Summary:
# Train - Loss: 0.2195, Acc: 89.79%, F1: 0.7877
# Val   - Loss: 0.5313, Acc: 77.19%, F1: 0.7690
# Learning Rate: 1.27e-06
#   Time - Epoch: 295.2s, Inference: 10.1ms
#
# ============================================================
# Epoch 30/30
# ============================================================
# Epoch 30 Training: 100%|██████████| 592/592 [04:25<00:00,  2.23it/s, Loss=0.2232, Acc=89.82%, LR=1.27e-06]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.5268, Acc=76.87%]
# 📊 Epoch 30 Summary:
# Train - Loss: 0.2232, Acc: 89.82%, F1: 0.7868
# Val   - Loss: 0.5268, Acc: 76.87%, F1: 0.7658
# Learning Rate: 1.00e-06
#   Time - Epoch: 295.1s, Inference: 9.4ms
#
# 🎉 Training completed!
# 📈 Best validation F1: 0.7711
# ⏱️  Average epoch time: 295.4s
# ⚡ Average inference time: 10.0ms

# %%
# cell 6: Test
test_loss, test_acc, test_f1 = trainer.test()
print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}, Test F1: {test_f1:.4f}")
# Out:
# ============================================================
# Testing Model
# ============================================================
# Model loaded from /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260208_134820-20mu7r8z/files/best_model.pth
# Testing: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=0.5863, Acc=73.21%]
# 📊 Test Results:
# Test Loss: 0.5863
# Test Accuracy: 73.21%
# Test F1 Score: 0.7522
# Average Inference Time per Image: 9.43 ms
#
# 📋 Detailed Classification Report:
#               precision    recall  f1-score   support
#
#   not_normal       0.88      0.59      0.71       345
#       normal       0.64      0.90      0.75       282
#
#     accuracy                           0.73       627
#    macro avg       0.76      0.75      0.73       627
# weighted avg       0.78      0.73      0.73       627
#
# Test Loss: 0.5863, Test Acc: 73.2057, Test F1: 0.7522

# %%
import os
final_model_path = os.path.join('ODIR-2019/results/', saved_model_name)
trainer.save_model(final_model_path)
# Out:
# Model saved to ODIR-2019/results/efficientnet-b4-odir-2019-pmgb-normal.pth

# %%
wandb.finish()
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>learning_rate</td><td>█████▇▇▇▇▆▆▆▅▅▅▄▄▃▃▃▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>test_acc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>train_acc</td><td>▁▂▃▄▅▄▅▅▅▆▅▆▆▆▆▇▇▇▇▇▇▇█▇██████</td></tr><tr><td>train_f1</td><td>▁▃▄▄▅▅▅▆▆▆▆▆▆▇▇▇▇▇█▇█▇████████</td></tr><tr><td>train_loss</td><td>█▆▆▅▅▅▄▄▄▃▄▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▃▂▄▄▅▅▆▆▆▇▇█▇▇▇▇▇▇█▇█▇███▇███</td></tr><tr><td>val_f1</td><td>▁▁▃▃▄▆▃▆▆▃▇▇▇▇▆▆█▇█▇▇▇▇█▇▇▇███</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>30</td></tr><tr><td>learning_rate</td><td>0.0</td></tr><tr><td>test_acc</td><td>73.20574</td></tr><tr><td>test_f1</td><td>0.75221</td></tr><tr><td>test_loss</td><td>0.58631</td></tr><tr><td>train_acc</td><td>89.82264</td></tr><tr><td>train_f1</td><td>0.78682</td></tr><tr><td>train_loss</td><td>0.2232</td></tr><tr><td>val_acc</td><td>76.874</td></tr><tr><td>val_f1</td><td>0.76575</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">efficientnet-b4_pmgb</strong> at: <a href='https://wandb.ai/samalo/odir-2019-binary-classification/runs/20mu7r8z' target="_blank">https://wandb.ai/samalo/odir-2019-binary-classification/runs/20mu7r8z</a><br> View project at: <a href='https://wandb.ai/samalo/odir-2019-binary-classification' target="_blank">https://wandb.ai/samalo/odir-2019-binary-classification</a><br>Synced 5 W&B file(s), 9 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260208_134820-20mu7r8z/logs</code>
