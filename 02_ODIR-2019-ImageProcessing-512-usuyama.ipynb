# %% [markdown]
# # Processing Images For Merged Dataset
#
# Here we enhance the images (training and testing) to improve the image quality using usuyama style ben graham

# %% [markdown]
# Define display images function

# %%
import os
import cv2
from matplotlib import pyplot as plt
def display_images(image_filenames:list[str], title="Image DataSet", col_count = 10):
    plt.suptitle(title, fontsize=20)
    img_count = len(image_filenames)
    plt.figure(figsize=(15, 15))
    for i in range(1, img_count+1):
        plt.subplot(5, col_count, i)
        image_path=image_filenames[i-1]
        image_name=os.path.basename(image_path)
        img = cv2.imread(image_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        plt.imshow(img, aspect="auto")
        plt.title(f"{image_name}")
        plt.axis(False)
    plt.show();

# %% [markdown]
# Define our image processor class

# %%
import cv2
import numpy as np
from pathlib import Path

class ODIRImageProcessor:
    """Simple processor for ODIR retinal images"""
    
    def __init__(self, output_size=512):
        self.output_size = output_size
    
    def process(self, input_path, output_path=None, skip_if_exist=True):
        """
        Process a single ODIR image
        
        Args:
            input_path: Path to input image
            output_path: Optional path to save result. If None, returns image array
        
        Returns:
            Processed image as numpy array
        """
        if skip_if_exist and output_path is not None:
            if os.path.exists(output_path):
                print(f"Skip as processed image existed: {output_path}")
                return

        # Read image
        img = cv2.imread(str(input_path))
        if img is None:
            raise ValueError(f"Cannot read image: {input_path}")
        
        # Convert BGR to RGB
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        
        # Call Preprocess script
        img = self.usuyama_prep(img=img)

        # Convert back to BGR for saving/display
        img_bgr = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        
        # Save if output path is provided
        if output_path:
            cv2.imwrite(str(output_path), img_bgr)
            print(f"Saved processed image to: {output_path}")
        
       # return img_bgr

    def resize_odir_image(self, img, target_size=512):
        """
        Combines Circular Cropping, Aspect-Ratio Resizing, and Padding.
        """
        # 1. Load and initial crop to remove obvious black dead space
        if img is None: return None
        
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        # Thresholding to find the retina boundary
        _, mask = cv2.threshold(gray, 10, 255, cv2.THRESH_BINARY)
        coords = cv2.findNonZero(mask)
        
        if coords is not None:
            x, y, w, h = cv2.boundingRect(coords)
            img = img[y:y+h, x:x+w]

        # 2. Letterbox Resize (Preserve Aspect Ratio)
        h, w = img.shape[:2]
        scale = target_size / max(h, w)
        new_w, new_h = int(w * scale), int(h * scale)
        
        # Use INTER_AREA for high-quality downsampling
        resized = cv2.resize(img, (new_w, new_h), interpolation=cv2.INTER_AREA)
        
        # 3. Create Square Canvas and Center
        final_img = np.zeros((target_size, target_size, 3), dtype=np.uint8)
        offset_y = (target_size - new_h) // 2
        offset_x = (target_size - new_w) // 2
        final_img[offset_y:offset_y+new_h, offset_x:offset_x+new_w] = resized
        
        return final_img
    def usuyama_prep(self, img):
        """Enhances vessels and normalizes lighting."""
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        # Circular Crop: Find non-black pixels and crop
        img = self.resize_odir_image(img, target_size=self.output_size)  # Crop to circular region
        blurred = cv2.GaussianBlur(img, (0, 0), 10)
        enhanced = cv2.addWeighted(img, 4, blurred, -4, 128)
        return enhanced

    def remove_outer_circle(self, a, p=0.9, r=256):
        b = np.zeros(a.shape, dtype=np.uint8)
        cv2.circle(b, (a.shape[1] // 2, a.shape[0] // 2), int(r * p), (1, 1, 1), -1, 8, 0)
        
        return a * b + 128 * (1 - b)
    
    def place_in_square(self, img, r, h=512, w=512):
        new_img = np.zeros((2 * r, 2 * r, 3), dtype=np.uint8)
        new_img += 128
        new_img[r - h // 2:r - h // 2 + img.shape[0], r - w // 2:r - w // 2 + img.shape[1]] = img
        
        return new_img
    def process_folder(self, input_folder, output_folder, skip_if_exist, extension=".jpg"):
        """
        Process all images in a folder
        """
        input_folder = Path(input_folder)
        output_folder = Path(output_folder)
        output_folder.mkdir(parents=True, exist_ok=True)
        
        image_files = list(input_folder.glob(f"*{extension}"))
        print(f"Found {len(image_files)} images to process")
        
        for img_path in image_files:
            output_path = output_folder / img_path.name
            try:
                self.process(img_path, output_path, skip_if_exist=skip_if_exist)
            except Exception as e:
                print(f"Error processing {img_path.name}: {e}")

# %% [markdown]
# Test on 1 image and then dispaly and compare

# %%
# !mkdir -p ODIR-2019/YOLO/processed_512u_merged

# %%
import os
input_folder="ODIR-2019/YOLO/preprocessed_merged"
output_folder="ODIR-2019/YOLO/processed_512u_merged"
processor = ODIRImageProcessor(output_size=512)

for root, dirs, files in os.walk(input_folder):
    for dir_name in dirs:
        source_dir=os.path.join(root, dir_name)
        target_dir=source_dir.replace(input_folder, output_folder)
        os.makedirs(target_dir, exist_ok=True)
        processor.process_folder(
            input_folder=source_dir,
            output_folder=target_dir,
            skip_if_exist=True,
            extension=".jpg"
        )
        processor.process_folder(
            input_folder=source_dir,
            output_folder=target_dir,
            skip_if_exist=True,
            extension=".png"
        )
# Out:
# Found 0 images to process
# Found 0 images to process
# Found 0 images to process
# Found 0 images to process
# Found 0 images to process
# Found 0 images to process
# Found 26 images to process
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/cataract/2108_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/cataract/294_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/cataract/0_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/cataract/2150_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/cataract/2159_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/cataract/1435_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/cataract/330_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/cataract/2243_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/cataract/2130_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/cataract/2183_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/cataract/726_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/cataract/2219_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/cataract/2227_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/cataract/2106_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/cataract/2208_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/cataract/2125_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/cataract/2185_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/cataract/2213_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/cataract/1415_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/cataract/2156_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/cataract/1454_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/cataract/1164_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/cataract/2198_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/cataract/2216_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/cataract/2262_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/cataract/2144_left.jpg
# Found 0 images to process
# Found 28 images to process
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/glaucoma/1503_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/glaucoma/1239_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/glaucoma/1371_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/glaucoma/1248_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/glaucoma/1473_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/glaucoma/1306_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/glaucoma/1963_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/glaucoma/1405_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/glaucoma/1964_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/glaucoma/1218_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/glaucoma/1319_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/glaucoma/1495_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/glaucoma/1492_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/glaucoma/1369_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/glaucoma/1345_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/glaucoma/1465_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/glaucoma/1222_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/glaucoma/1214_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/glaucoma/1425_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/glaucoma/1406_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/glaucoma/1215_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/glaucoma/1388_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/glaucoma/1439_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/glaucoma/1247_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/glaucoma/1267_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/glaucoma/1229_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/glaucoma/1220_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/glaucoma/1227_left.jpg
# Found 0 images to process
# Found 68 images to process
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/1080_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/1016_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/125_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/816_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/1681_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/661_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/483_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/665_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/510_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/1264_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/611_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/865_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/287_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/1176_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/644_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/1032_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/180_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/883_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/517_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/491_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/357_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/969_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/749_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/269_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/204_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/575_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/858_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/360_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/1120_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/1124_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/487_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/670_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/747_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/545_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/1116_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/1109_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/1383_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/660_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/542_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/643_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/1015_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/573_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/1097_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/2034_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/676_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/880_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/554_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/52_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/858_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/680_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/602_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/496_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/326_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/1019_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/511_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/881_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/460_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/344_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/278_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/286_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/231_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/1674_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/930_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/710_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/165_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/304_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/657_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/other/450_left.jpg
# Found 0 images to process
# Found 13 images to process
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/hypertension/783_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/hypertension/4592_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/hypertension/4579_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/hypertension/499_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/hypertension/790_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/hypertension/675_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/hypertension/2052_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/hypertension/4562_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/hypertension/62_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/hypertension/1045_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/hypertension/355_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/hypertension/116_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/hypertension/983_left.jpg
# Found 0 images to process
# Found 160 images to process
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/diabetes/4304_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/diabetes/794_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/diabetes/4558_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/diabetes/309_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/diabetes/755_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/diabetes/1068_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/diabetes/492_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/diabetes/4599_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/diabetes/604_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/diabetes/4443_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/diabetes/4174_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/diabetes/446_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/diabetes/4054_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/diabetes/4608_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/diabetes/2262_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/diabetes/445_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/diabetes/4247_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/diabetes/4584_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/diabetes/4636_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/diabetes/4629_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/diabetes/4532_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/diabetes/4404_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/diabetes/4035_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/diabetes/4090_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/diabetes
left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/normal/2584_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/normal/2573_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/normal/2366_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/normal/2508_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/normal/354_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/normal/2360_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/normal/2738_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/normal/35_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/normal/2736_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/normal/1168_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/normal/2838_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/normal/2951_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/val/normal/14_left.jpg
# ...
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma224.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma671.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma938.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1341.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/2063_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma94.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma75.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma684.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma36.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/1440_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1245.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma504.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma4.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1171.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma116.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1065.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/1246_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1127.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/1309_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma150.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1291.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma29.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1251.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma578.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma881.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma330.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma596.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma428.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma406.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma584.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1273.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma359.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma822.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/1282_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1181.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma149.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma241.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/1365_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma267.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma902.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1048.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma573.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma665.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma661.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma374.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1029.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/1498_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/1402_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma806.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/1352_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma193.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma493.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1031.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma379.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma751.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma745.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma506.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/1214_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma741.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1297.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma65.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma533.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1000.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma382.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1025.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1265.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma628.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1076.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma395.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma727.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma668.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma422.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma680.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1034.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma669.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/1231_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma38.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1102.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma771.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma398.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma864.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1189.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1155.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma729.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma333.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma827.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/1442_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma632.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma848.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma475.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1043.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma616.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma173.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma721.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/1287_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma412.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma388.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma744.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1339.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma564.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1010.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/1259_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma168.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1095.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1071.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1156.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1331.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma984.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1143.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1003.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1328.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma468.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1278.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma425.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma566.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma22.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma397.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1248.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1282.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/1327_left.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma511.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1285.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma555.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1049.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma645.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1165.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1179.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma390.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1292.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/1309_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma134.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1241.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/1254_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1207.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma206.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma801.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma287.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/1453_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/1408_right.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma809.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma606.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma790.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma494.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1234.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma1321.jpg
# Saved processed image to: ODIR-2019/YOLO/processed_512ua_merged/train/glaucoma/Glaucoma924.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 11
#       9 target_dir=source_dir.replace(input_folder, output_folder)
#      10 os.makedirs(target_dir, exist_ok=True)
# ---> 11 processor.process_folder(
#      12     input_folder=source_dir,
#      13     output_folder=target_dir,
#      14     skip_if_exist=True,
#      15     extension=".jpg"
#      16 )
#      17 processor.process_folder(
#      18     input_folder=source_dir,
#      19     output_folder=target_dir,
#      20     skip_if_exist=True,
#      21     extension=".png"
#      22 )
#
# Cell In[2], line 114, in ODIRImageProcessor.process_folder(self, input_folder, output_folder, skip_if_exist, extension)
#     112 output_path = output_folder / img_path.name
#     113 try:
# --> 114     self.process(img_path, output_path, skip_if_exist=skip_if_exist)
#     115 except Exception as e:
#     116     print(f"Error processing {img_path.name}: {e}")
#
# Cell In[2], line 36, in ODIRImageProcessor.process(self, input_path, output_path, skip_if_exist)
#      33 img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#      35 # Call Preprocess script
# ---> 36 img = self.usuyama_prep(img=img)
#      38 # Convert back to BGR for saving/display
#      39 img_bgr = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
#
# Cell In[2], line 83, in ODIRImageProcessor.usuyama_prep(self, img)
#      81 img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#      82 # Circular Crop: Find non-black pixels and crop
# ---> 83 img = self.resize_odir_image(img, target_size=self.output_size)  # Crop to circular region
#      84 blurred = cv2.GaussianBlur(img, (0, 0), 10)
#      85 enhanced = cv2.addWeighted(img, 4, blurred, -4, 128)
#
# Cell In[2], line 58, in ODIRImageProcessor.resize_odir_image(self, img, target_size)
#      56 # Thresholding to find the retina boundary
#      57 _, mask = cv2.threshold(gray, 10, 255, cv2.THRESH_BINARY)
# ---> 58 coords = cv2.findNonZero(mask)
#      60 if coords is not None:
#      61     x, y, w, h = cv2.boundingRect(coords)
#
# KeyboardInterrupt:
