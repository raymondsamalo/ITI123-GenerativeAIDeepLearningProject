# %%
# %%capture
# !pip install efficientnet-pytorch wandb torch torchvision scikit-learn seaborn tqdm

# %%
import sys
sys.path.append('.')

from efficient_net import EfficientNetTrainer

# %%
from util import get_train_device

device_for_training = get_train_device()
# Out:
# Using NVIDIA GPU (CUDA)

# %% [markdown]
# We use EfficientNet-B4 as it was reported to perform well in term of F1 at the cost of 4 times slower than EfficientNet-B0

# %%
import wandb
config = {
    'data_dir': './ODIR-2019/YOLO/preprocessed',  # Your dataset path
    'model_name': 'efficientnet-b4',
    'num_classes': 8,
    'image_size': 512,
    'batch_size': 16,  # Smaller for Jupyter
    'epochs': 30,
    'lr': 0.001,
    'weight_decay': 1e-4,
    'optimizer': 'adamw',
    'scheduler': 'cosine',
    'fine_tune': True,
    'unfreeze_blocks': 3,
    'label_smoothing': 0.1,
    'num_workers': 2,  # Lower for Jupyter
    'use_amp': True,
    'seed': 42
}
wandb.init(project="odir-2019", name="efficientnet-b4_preprocessed")
trainer = EfficientNetTrainer(config)
trainer.train()
# Out:
# wandb: Currently logged in as: raymond-samalo (samalo) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260127_115507-c102ig8o</code>
# Syncing run <strong><a href='https://wandb.ai/samalo/odir-2019/runs/c102ig8o' target="_blank">efficientnet-b4_preprocessed</a></strong> to <a href='https://wandb.ai/samalo/odir-2019' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/samalo/odir-2019' target="_blank">https://wandb.ai/samalo/odir-2019</a>
#  View run at <a href='https://wandb.ai/samalo/odir-2019/runs/c102ig8o' target="_blank">https://wandb.ai/samalo/odir-2019/runs/c102ig8o</a>
# Using device: cuda
# Loading efficientnet-b4 with 8 classes...
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b4-6ed6700e.pth" to /home/ray/.cache/torch/hub/checkpoints/efficientnet-b4-6ed6700e.pth
# 100%|██████████| 74.4M/74.4M [00:07<00:00, 10.8MB/s]
# Loaded pretrained weights for efficientnet-b4
# Loading datasets from ./ODIR-2019/YOLO/preprocessed...
# Found 5014 images in train split across 8 classes
#
# Class distribution in train split:
#   normal: 2252 samples (44.9%)
#   diabetes: 1281 samples (25.5%)
#   glaucoma: 225 samples (4.5%)
#   cataract: 213 samples (4.2%)
#   ageing: 213 samples (4.2%)
#   hypertension: 102 samples (2.0%)
#   myopia: 183 samples (3.6%)
#   other: 545 samples (10.9%)
# Found 627 images in val split across 8 classes
#
# Class distribution in val split:
#   normal: 282 samples (45.0%)
#   diabetes: 160 samples (25.5%)
#   glaucoma: 28 samples (4.5%)
#   cataract: 26 samples (4.1%)
#   ageing: 27 samples (4.3%)
#   hypertension: 13 samples (2.1%)
#   myopia: 23 samples (3.7%)
#   other: 68 samples (10.8%)
# Found 627 images in test split across 8 classes
#
# Class distribution in test split:
#   normal: 282 samples (45.0%)
#   diabetes: 160 samples (25.5%)
#   glaucoma: 28 samples (4.5%)
#   cataract: 27 samples (4.3%)
#   ageing: 26 samples (4.1%)
#   hypertension: 13 samples (2.1%)
#   myopia: 23 samples (3.7%)
#   other: 68 samples (10.8%)
#
# ============================================================
# Epoch 1/30
# ============================================================
# Epoch 1 Training: 100%|██████████| 313/313 [02:26<00:00,  2.14it/s, Loss=1.5165, Acc=50.06%, LR=1.00e-04]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.3741, Acc=60.61%]
# Epoch 1 Summary:
# Train - Loss: 1.5165, Acc: 50.06%, F1: 0.4234
# Val   - Loss: 1.3741, Acc: 60.61%, F1: 0.5379
# Learning Rate: 9.97e-05
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260127_115507-c102ig8o/files/best_model.pth
# ✅ New best model saved with F1: 0.5379
#
# ============================================================
# Epoch 2/30
# ============================================================
# Epoch 2 Training: 100%|██████████| 313/313 [02:20<00:00,  2.22it/s, Loss=1.3833, Acc=55.93%, LR=9.97e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.3071, Acc=60.61%]
# Epoch 2 Summary:
# Train - Loss: 1.3833, Acc: 55.93%, F1: 0.5039
# Val   - Loss: 1.3071, Acc: 60.61%, F1: 0.5585
# Learning Rate: 9.89e-05
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260127_115507-c102ig8o/files/best_model.pth
# ✅ New best model saved with F1: 0.5585
#
# ============================================================
# Epoch 3/30
# ============================================================
# Epoch 3 Training: 100%|██████████| 313/313 [02:20<00:00,  2.22it/s, Loss=1.3248, Acc=59.80%, LR=9.89e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2589, Acc=64.75%]
# Epoch 3 Summary:
# Train - Loss: 1.3248, Acc: 59.80%, F1: 0.5548
# Val   - Loss: 1.2589, Acc: 64.75%, F1: 0.6188
# Learning Rate: 9.76e-05
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260127_115507-c102ig8o/files/best_model.pth
# ✅ New best model saved with F1: 0.6188
#
# ============================================================
# Epoch 4/30
# ============================================================
# Epoch 4 Training: 100%|██████████| 313/313 [02:20<00:00,  2.22it/s, Loss=1.3015, Acc=61.14%, LR=9.76e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2534, Acc=64.75%]
# Epoch 4 Summary:
# Train - Loss: 1.3015, Acc: 61.14%, F1: 0.5721
# Val   - Loss: 1.2534, Acc: 64.75%, F1: 0.6206
# Learning Rate: 9.57e-05
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260127_115507-c102ig8o/files/best_model.pth
# ✅ New best model saved with F1: 0.6206
#
# ============================================================
# Epoch 5/30
# ============================================================
# Epoch 5 Training: 100%|██████████| 313/313 [02:20<00:00,  2.22it/s, Loss=1.2597, Acc=61.82%, LR=9.57e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2489, Acc=65.39%]
# Epoch 5 Summary:
# Train - Loss: 1.2597, Acc: 61.82%, F1: 0.5865
# Val   - Loss: 1.2489, Acc: 65.39%, F1: 0.6110
# Learning Rate: 9.34e-05
#
# ============================================================
# Epoch 6/30
# ============================================================
# Epoch 6 Training: 100%|██████████| 313/313 [02:20<00:00,  2.22it/s, Loss=1.2409, Acc=62.64%, LR=9.34e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2167, Acc=66.35%]
# Epoch 6 Summary:
# Train - Loss: 1.2409, Acc: 62.64%, F1: 0.5981
# Val   - Loss: 1.2167, Acc: 66.35%, F1: 0.6308
# Learning Rate: 9.05e-05
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260127_115507-c102ig8o/files/best_model.pth
# ✅ New best model saved with F1: 0.6308
#
# ============================================================
# Epoch 7/30
# ============================================================
# Epoch 7 Training: 100%|██████████| 313/313 [02:20<00:00,  2.22it/s, Loss=1.2301, Acc=62.96%, LR=9.05e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2155, Acc=67.30%]
# Epoch 7 Summary:
# Train - Loss: 1.2301, Acc: 62.96%, F1: 0.6028
# Val   - Loss: 1.2155, Acc: 67.30%, F1: 0.6508
# Learning Rate: 8.73e-05
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260127_115507-c102ig8o/files/best_model.pth
# ✅ New best model saved with F1: 0.6508
#
# ============================================================
# Epoch 8/30
# ============================================================
# Epoch 8 Training: 100%|██████████| 313/313 [02:20<00:00,  2.22it/s, Loss=1.2191, Acc=64.20%, LR=8.73e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2257, Acc=66.19%]
# Epoch 8 Summary:
# Train - Loss: 1.2191, Acc: 64.20%, F1: 0.6155
# Val   - Loss: 1.2257, Acc: 66.19%, F1: 0.6413
# Learning Rate: 8.36e-05
#
# ============================================================
# Epoch 9/30
# ============================================================
# Epoch 9 Training: 100%|██████████| 313/313 [02:20<00:00,  2.22it/s, Loss=1.1911, Acc=65.34%, LR=8.36e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2369, Acc=64.91%]
# Epoch 9 Summary:
# Train - Loss: 1.1911, Acc: 65.34%, F1: 0.6307
# Val   - Loss: 1.2369, Acc: 64.91%, F1: 0.6359
# Learning Rate: 7.96e-05
#
# ============================================================
# Epoch 10/30
# ============================================================
# Epoch 10 Training: 100%|██████████| 313/313 [02:20<00:00,  2.22it/s, Loss=1.1655, Acc=66.91%, LR=7.96e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.1857, Acc=66.83%]
# Epoch 10 Summary:
# Train - Loss: 1.1655, Acc: 66.91%, F1: 0.6486
# Val   - Loss: 1.1857, Acc: 66.83%, F1: 0.6553
# Learning Rate: 7.52e-05
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260127_115507-c102ig8o/files/best_model.pth
# ✅ New best model saved with F1: 0.6553
#
# ============================================================
# Epoch 11/30
# ============================================================
# Epoch 11 Training: 100%|██████████| 313/313 [02:20<00:00,  2.22it/s, Loss=1.1628, Acc=66.93%, LR=7.52e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2051, Acc=66.35%]
# Epoch 11 Summary:
# Train - Loss: 1.1628, Acc: 66.93%, F1: 0.6508
# Val   - Loss: 1.2051, Acc: 66.35%, F1: 0.6372
# Learning Rate: 7.06e-05
#
# ============================================================
# Epoch 12/30
# ============================================================
# Epoch 12 Training: 100%|██████████| 313/313 [02:20<00:00,  2.22it/s, Loss=1.1444, Acc=67.67%, LR=7.06e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.1984, Acc=67.62%]
# Epoch 12 Summary:
# Train - Loss: 1.1444, Acc: 67.67%, F1: 0.6570
# Val   - Loss: 1.1984, Acc: 67.62%, F1: 0.6501
# Learning Rate: 6.58e-05
#
# ============================================================
# Epoch 13/30
# ============================================================
# Epoch 13 Training: 100%|██████████| 313/313 [02:20<00:00,  2.22it/s, Loss=1.1356, Acc=68.31%, LR=6.58e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.1720, Acc=68.58%]
# Epoch 13 Summary:
# Train - Loss: 1.1356, Acc: 68.31%, F1: 0.6678
# Val   - Loss: 1.1720, Acc: 68.58%, F1: 0.6713
# Learning Rate: 6.08e-05
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260127_115507-c102ig8o/files/best_model.pth
# ✅ New best model saved with F1: 0.6713
#
# ============================================================
# Epoch 14/30
# ============================================================
# Epoch 14 Training: 100%|██████████| 313/313 [02:20<00:00,  2.22it/s, Loss=1.1148, Acc=68.67%, LR=6.08e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.1763, Acc=67.78%]
# Epoch 14 Summary:
# Train - Loss: 1.1148, Acc: 68.67%, F1: 0.6720
# Val   - Loss: 1.1763, Acc: 67.78%, F1: 0.6667
# Learning Rate: 5.57e-05
#
# ============================================================
# Epoch 15/30
# ============================================================
# Epoch 15 Training: 100%|██████████| 313/313 [02:20<00:00,  2.22it/s, Loss=1.0995, Acc=70.07%, LR=5.57e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.1702, Acc=67.94%]
# Epoch 15 Summary:
# Train - Loss: 1.0995, Acc: 70.07%, F1: 0.6883
# Val   - Loss: 1.1702, Acc: 67.94%, F1: 0.6611
# Learning Rate: 5.05e-05
#
# ============================================================
# Epoch 16/30
# ============================================================
# Epoch 16 Training: 100%|██████████| 313/313 [02:20<00:00,  2.22it/s, Loss=1.1027, Acc=69.79%, LR=5.05e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.1841, Acc=67.94%]
# Epoch 16 Summary:
# Train - Loss: 1.1027, Acc: 69.79%, F1: 0.6846
# Val   - Loss: 1.1841, Acc: 67.94%, F1: 0.6658
# Learning Rate: 4.53e-05
#
# ============================================================
# Epoch 17/30
# ============================================================
# Epoch 17 Training: 100%|██████████| 313/313 [02:20<00:00,  2.22it/s, Loss=1.0973, Acc=69.71%, LR=4.53e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.1778, Acc=69.06%]
# Epoch 17 Summary:
# Train - Loss: 1.0973, Acc: 69.71%, F1: 0.6841
# Val   - Loss: 1.1778, Acc: 69.06%, F1: 0.6782
# Learning Rate: 4.02e-05
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260127_115507-c102ig8o/files/best_model.pth
# ✅ New best model saved with F1: 0.6782
#
# ============================================================
# Epoch 18/30
# ============================================================
# Epoch 18 Training: 100%|██████████| 313/313 [02:20<00:00,  2.22it/s, Loss=1.0833, Acc=71.25%, LR=4.02e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.1884, Acc=69.54%]
# Epoch 18 Summary:
# Train - Loss: 1.0833, Acc: 71.25%, F1: 0.7002
# Val   - Loss: 1.1884, Acc: 69.54%, F1: 0.6845
# Learning Rate: 3.52e-05
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260127_115507-c102ig8o/files/best_model.pth
# ✅ New best model saved with F1: 0.6845
#
# ============================================================
# Epoch 19/30
# ============================================================
# Epoch 19 Training: 100%|██████████| 313/313 [02:20<00:00,  2.22it/s, Loss=1.0750, Acc=71.53%, LR=3.52e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.1923, Acc=69.22%]
# Epoch 19 Summary:
# Train - Loss: 1.0750, Acc: 71.53%, F1: 0.7035
# Val   - Loss: 1.1923, Acc: 69.22%, F1: 0.6799
# Learning Rate: 3.04e-05
#
# ============================================================
# Epoch 20/30
# ============================================================
# Epoch 20 Training: 100%|██████████| 313/313 [02:21<00:00,  2.22it/s, Loss=1.0493, Acc=72.68%, LR=3.04e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.1938, Acc=68.42%]
# Epoch 20 Summary:
# Train - Loss: 1.0493, Acc: 72.68%, F1: 0.7155
# Val   - Loss: 1.1938, Acc: 68.42%, F1: 0.6746
# Learning Rate: 2.58e-05
#
# ============================================================
# Epoch 21/30
# ============================================================
# Epoch 21 Training: 100%|██████████| 313/313 [02:20<00:00,  2.22it/s, Loss=1.0492, Acc=72.46%, LR=2.58e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.1824, Acc=69.22%]
# Epoch 21 Summary:
# Train - Loss: 1.0492, Acc: 72.46%, F1: 0.7135
# Val   - Loss: 1.1824, Acc: 69.22%, F1: 0.6781
# Learning Rate: 2.14e-05
#
# ============================================================
# Epoch 22/30
# ============================================================
# Epoch 22 Training: 100%|██████████| 313/313 [02:20<00:00,  2.22it/s, Loss=1.0465, Acc=72.06%, LR=2.14e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.1771, Acc=68.90%]
# Epoch 22 Summary:
# Train - Loss: 1.0465, Acc: 72.06%, F1: 0.7082
# Val   - Loss: 1.1771, Acc: 68.90%, F1: 0.6759
# Learning Rate: 1.74e-05
#
# ============================================================
# Epoch 23/30
# ============================================================
# Epoch 23 Training: 100%|██████████| 313/313 [02:20<00:00,  2.22it/s, Loss=1.0316, Acc=73.66%, LR=1.74e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.1788, Acc=68.74%]
# Epoch 23 Summary:
# Train - Loss: 1.0316, Acc: 73.66%, F1: 0.7278
# Val   - Loss: 1.1788, Acc: 68.74%, F1: 0.6759
# Learning Rate: 1.37e-05
#
# ============================================================
# Epoch 24/30
# ============================================================
# Epoch 24 Training: 100%|██████████| 313/313 [02:20<00:00,  2.22it/s, Loss=1.0475, Acc=71.90%, LR=1.37e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.1784, Acc=69.54%]
# Epoch 24 Summary:
# Train - Loss: 1.0475, Acc: 71.90%, F1: 0.7085
# Val   - Loss: 1.1784, Acc: 69.54%, F1: 0.6806
# Learning Rate: 1.05e-05
#
# ============================================================
# Epoch 25/30
# ============================================================
# Epoch 25 Training: 100%|██████████| 313/313 [02:20<00:00,  2.22it/s, Loss=1.0387, Acc=72.60%, LR=1.05e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.1766, Acc=69.70%]
# Epoch 25 Summary:
# Train - Loss: 1.0387, Acc: 72.60%, F1: 0.7154
# Val   - Loss: 1.1766, Acc: 69.70%, F1: 0.6824
# Learning Rate: 7.63e-06
#
# ============================================================
# Epoch 26/30
# ============================================================
# Epoch 26 Training: 100%|██████████| 313/313 [02:20<00:00,  2.22it/s, Loss=1.0279, Acc=73.14%, LR=7.63e-06]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.1831, Acc=68.90%]
# Epoch 26 Summary:
# Train - Loss: 1.0279, Acc: 73.14%, F1: 0.7197
# Val   - Loss: 1.1831, Acc: 68.90%, F1: 0.6735
# Learning Rate: 5.28e-06
#
# ============================================================
# Epoch 27/30
# ============================================================
# Epoch 27 Training: 100%|██████████| 313/313 [02:20<00:00,  2.22it/s, Loss=1.0213, Acc=74.12%, LR=5.28e-06]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.1812, Acc=68.90%]
# Epoch 27 Summary:
# Train - Loss: 1.0213, Acc: 74.12%, F1: 0.7320
# Val   - Loss: 1.1812, Acc: 68.90%, F1: 0.6744
# Learning Rate: 3.42e-06
#
# ============================================================
# Epoch 28/30
# ============================================================
# Epoch 28 Training: 100%|██████████| 313/313 [02:20<00:00,  2.22it/s, Loss=1.0293, Acc=73.24%, LR=3.42e-06]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.1824, Acc=68.90%]
# Epoch 28 Summary:
# Train - Loss: 1.0293, Acc: 73.24%, F1: 0.7229
# Val   - Loss: 1.1824, Acc: 68.90%, F1: 0.6741
# Learning Rate: 2.08e-06
#
# ============================================================
# Epoch 29/30
# ============================================================
# Epoch 29 Training: 100%|██████████| 313/313 [02:20<00:00,  2.22it/s, Loss=1.0342, Acc=73.12%, LR=2.08e-06]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.1796, Acc=68.74%]
# Epoch 29 Summary:
# Train - Loss: 1.0342, Acc: 73.12%, F1: 0.7211
# Val   - Loss: 1.1796, Acc: 68.74%, F1: 0.6735
# Learning Rate: 1.27e-06
#
# ============================================================
# Epoch 30/30
# ============================================================
# Epoch 30 Training: 100%|██████████| 313/313 [02:20<00:00,  2.22it/s, Loss=1.0238, Acc=73.00%, LR=1.27e-06]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.1801, Acc=69.38%]
# Epoch 30 Summary:
# Train - Loss: 1.0238, Acc: 73.00%, F1: 0.7207
# Val   - Loss: 1.1801, Acc: 69.38%, F1: 0.6782
# Learning Rate: 1.00e-06

# %%
# cell 6: Test
test_loss, test_acc, test_f1 = trainer.test()
print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}, Test F1: {test_f1:.4f}")
# Out:
# ============================================================
# Testing Model
# ============================================================
# Model loaded from /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260127_115507-c102ig8o/files/best_model.pth
# Testing: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.1453, Acc=66.99%]
# 📊 Test Results:
# Test Loss: 1.1453
# Test Accuracy: 66.99%
# Test Weighted F1 Score: 0.6600
#
# 📋 Detailed Classification Report:
#               precision    recall  f1-score   support
#
#       normal       0.68      0.76      0.72       282
#     diabetes       0.69      0.64      0.67       160
#     glaucoma       0.45      0.54      0.49        28
#     cataract       0.81      0.81      0.81        27
#       ageing       0.63      0.73      0.68        26
# hypertension       0.20      0.08      0.11        13
#       myopia       0.78      0.91      0.84        23
#        other       0.60      0.35      0.44        68
#
#     accuracy                           0.67       627
#    macro avg       0.61      0.60      0.60       627
# weighted avg       0.66      0.67      0.66       627
#
# Test Loss: 1.1453, Test Acc: 66.9856, Test F1: 0.6600

# %%
import os
final_model_path = os.path.join('ODIR-2019/results/', 'efficientnet-b4_preprocessed.pth')
trainer.save_model(final_model_path)
# Out:
# Model saved to ODIR-2019/results/efficientnet-b4_preprocessed.pth

# %%
wandb.finish()
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>learning_rate</td><td>█████▇▇▇▇▆▆▆▅▅▅▄▄▃▃▃▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>test_acc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>train_acc</td><td>▁▃▄▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇▇██▇█▇██████</td></tr><tr><td>train_f1</td><td>▁▃▄▄▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇██▇█▇██████</td></tr><tr><td>train_loss</td><td>█▆▅▅▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▄▄▅▅▆▅▄▆▅▆▇▇▇▇███▇█▇▇██▇▇▇▇█</td></tr><tr><td>val_f1</td><td>▁▂▅▅▄▅▆▆▆▇▆▆▇▇▇▇█████████▇██▇█</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>30</td></tr><tr><td>learning_rate</td><td>0.0</td></tr><tr><td>test_acc</td><td>66.98565</td></tr><tr><td>test_f1</td><td>0.66004</td></tr><tr><td>test_loss</td><td>1.14532</td></tr><tr><td>train_acc</td><td>73.00319</td></tr><tr><td>train_f1</td><td>0.7207</td></tr><tr><td>train_loss</td><td>1.02376</td></tr><tr><td>val_acc</td><td>69.37799</td></tr><tr><td>val_f1</td><td>0.67824</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">efficientnet-b4_preprocessed</strong> at: <a href='https://wandb.ai/samalo/odir-2019/runs/c102ig8o' target="_blank">https://wandb.ai/samalo/odir-2019/runs/c102ig8o</a><br> View project at: <a href='https://wandb.ai/samalo/odir-2019' target="_blank">https://wandb.ai/samalo/odir-2019</a><br>Synced 5 W&B file(s), 9 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260127_115507-c102ig8o/logs</code>
