# %% [markdown]
# # EfficientNet-B4 Processed Merged Usuyama
#
#
# Here we run experiment with ODIR-2019 Usuyama enhanced Processed images and additional training images from Ocular Diseases DataSet
# except for Normal which we leave the ODIR-2019 original images as it is

# %%
data_dir = './ODIR-2019/YOLO/processed_512u_merged'  # Your dataset path
model_name = 'efficientnet-b4'
saved_model_name = 'efficientnet-b4-odir-2019-pmu.pth'
wandb_project = "odir-2019"
wandb_run_name = 'efficientnet-b4_pmu'

# %% [markdown]
# The following codes are generic or the same across experiments

# %%
# %%capture
# !pip install efficientnet-pytorch wandb torch torchvision scikit-learn seaborn tqdm

# %%
import sys
sys.path.append('.')

from efficient_net import EfficientNetTrainer

# %%
from util import get_train_device

device_for_training = get_train_device()
# Out:
# Using NVIDIA GPU (CUDA)

# %%
import wandb
config = {
    'data_dir': data_dir,
    'model_name': model_name,
    'num_classes': 8,
    'image_size': 512,
    'batch_size': 16,  # Smaller for Jupyter
    'epochs': 30,
    'lr': 0.001,
    'weight_decay': 1e-4,
    'optimizer': 'adamw',
    'scheduler': 'cosine',
    'fine_tune': True,
    'unfreeze_blocks': 3,
    'label_smoothing': 0.1,
    'num_workers': 2,  # Lower for Jupyter
    'use_amp': True,
    'seed': 42
}
wandb.init(project=wandb_project, name=wandb_run_name, config=config)
trainer = EfficientNetTrainer(config)
trainer.train()
# Out:
# wandb: Currently logged in as: raymond-samalo (samalo) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260223_081229-mgonr0z6</code>
# Syncing run <strong><a href='https://wandb.ai/samalo/odir-2019/runs/mgonr0z6' target="_blank">efficientnet-b4_pmu</a></strong> to <a href='https://wandb.ai/samalo/odir-2019' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/samalo/odir-2019' target="_blank">https://wandb.ai/samalo/odir-2019</a>
#  View run at <a href='https://wandb.ai/samalo/odir-2019/runs/mgonr0z6' target="_blank">https://wandb.ai/samalo/odir-2019/runs/mgonr0z6</a>
# Using device: cuda
# Loading efficientnet-b4 with 8 classes...
# Loaded pretrained weights for efficientnet-b4
# Loading datasets from ./ODIR-2019/YOLO/processed_512u_merged...
# Found 9478 images in train split across 8 classes
#
# Class distribution in train split:
#   normal: 2252 samples (23.8%)
#   diabetes: 2790 samples (29.4%)
#   glaucoma: 1574 samples (16.6%)
#   cataract: 724 samples (7.6%)
#   ageing: 724 samples (7.6%)
#   hypertension: 394 samples (4.2%)
#   myopia: 475 samples (5.0%)
#   other: 545 samples (5.8%)
# Found 627 images in val split across 8 classes
#
# Class distribution in val split:
#   normal: 282 samples (45.0%)
#   diabetes: 160 samples (25.5%)
#   glaucoma: 28 samples (4.5%)
#   cataract: 26 samples (4.1%)
#   ageing: 27 samples (4.3%)
#   hypertension: 13 samples (2.1%)
#   myopia: 23 samples (3.7%)
#   other: 68 samples (10.8%)
# Found 627 images in test split across 8 classes
#
# Class distribution in test split:
#   normal: 282 samples (45.0%)
#   diabetes: 160 samples (25.5%)
#   glaucoma: 28 samples (4.5%)
#   cataract: 27 samples (4.3%)
#   ageing: 26 samples (4.1%)
#   hypertension: 13 samples (2.1%)
#   myopia: 23 samples (3.7%)
#   other: 68 samples (10.8%)
#
# 📊 Dataset Statistics:
#    Train samples: 9478
#    Val samples:   627
#    Test samples:  627
#    Image size:    512
#    Batch size:    16
#
# ============================================================
# Epoch 1/30
# ============================================================
# Epoch 1 Training: 100%|██████████| 592/592 [04:33<00:00,  2.17it/s, Loss=1.2994, Acc=60.31%, LR=1.00e-04]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.34it/s, Loss=1.4999, Acc=54.39%]
# 📊 Epoch 1 Summary:
# Train - Loss: 1.2994, Acc: 60.31%, F1: 0.5804
# Val   - Loss: 1.4999, Acc: 54.39%, F1: 0.4800
# Learning Rate: 9.97e-05
#   Time - Epoch: 302.8s, Inference: 19.8ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260223_081229-mgonr0z6/files/best_model.pth
# ✅ New best model saved with F1: 0.4800
#
# ============================================================
# Epoch 2/30
# ============================================================
# Epoch 2 Training: 100%|██████████| 592/592 [04:27<00:00,  2.21it/s, Loss=1.1344, Acc=66.62%, LR=9.97e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.3675, Acc=59.81%]
# 📊 Epoch 2 Summary:
# Train - Loss: 1.1344, Acc: 66.62%, F1: 0.6521
# Val   - Loss: 1.3675, Acc: 59.81%, F1: 0.5501
# Learning Rate: 9.89e-05
#   Time - Epoch: 297.2s, Inference: 11.9ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260223_081229-mgonr0z6/files/best_model.pth
# ✅ New best model saved with F1: 0.5501
#
# ============================================================
# Epoch 3/30
# ============================================================
# Epoch 3 Training: 100%|██████████| 592/592 [04:27<00:00,  2.21it/s, Loss=1.0923, Acc=68.80%, LR=9.89e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.2992, Acc=62.68%]
# 📊 Epoch 3 Summary:
# Train - Loss: 1.0923, Acc: 68.80%, F1: 0.6775
# Val   - Loss: 1.2992, Acc: 62.68%, F1: 0.5926
# Learning Rate: 9.76e-05
#   Time - Epoch: 297.5s, Inference: 13.0ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260223_081229-mgonr0z6/files/best_model.pth
# ✅ New best model saved with F1: 0.5926
#
# ============================================================
# Epoch 4/30
# ============================================================
# Epoch 4 Training: 100%|██████████| 592/592 [04:27<00:00,  2.21it/s, Loss=1.0677, Acc=69.44%, LR=9.76e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.2931, Acc=61.72%]
# 📊 Epoch 4 Summary:
# Train - Loss: 1.0677, Acc: 69.44%, F1: 0.6851
# Val   - Loss: 1.2931, Acc: 61.72%, F1: 0.6001
# Learning Rate: 9.57e-05
#   Time - Epoch: 296.9s, Inference: 13.0ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260223_081229-mgonr0z6/files/best_model.pth
# ✅ New best model saved with F1: 0.6001
#
# ============================================================
# Epoch 5/30
# ============================================================
# Epoch 5 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=1.0370, Acc=70.65%, LR=9.57e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.2485, Acc=62.52%]
# 📊 Epoch 5 Summary:
# Train - Loss: 1.0370, Acc: 70.65%, F1: 0.6994
# Val   - Loss: 1.2485, Acc: 62.52%, F1: 0.6127
# Learning Rate: 9.34e-05
#   Time - Epoch: 296.4s, Inference: 10.8ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260223_081229-mgonr0z6/files/best_model.pth
# ✅ New best model saved with F1: 0.6127
#
# ============================================================
# Epoch 6/30
# ============================================================
# Epoch 6 Training: 100%|██████████| 592/592 [04:27<00:00,  2.21it/s, Loss=1.0217, Acc=71.14%, LR=9.34e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.2563, Acc=63.96%]
# 📊 Epoch 6 Summary:
# Train - Loss: 1.0217, Acc: 71.14%, F1: 0.7037
# Val   - Loss: 1.2563, Acc: 63.96%, F1: 0.6161
# Learning Rate: 9.05e-05
#   Time - Epoch: 297.0s, Inference: 10.8ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260223_081229-mgonr0z6/files/best_model.pth
# ✅ New best model saved with F1: 0.6161
#
# ============================================================
# Epoch 7/30
# ============================================================
# Epoch 7 Training: 100%|██████████| 592/592 [04:27<00:00,  2.21it/s, Loss=0.9959, Acc=72.65%, LR=9.05e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.2416, Acc=64.11%]
# 📊 Epoch 7 Summary:
# Train - Loss: 0.9959, Acc: 72.65%, F1: 0.7196
# Val   - Loss: 1.2416, Acc: 64.11%, F1: 0.6220
# Learning Rate: 8.73e-05
#   Time - Epoch: 297.0s, Inference: 10.7ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260223_081229-mgonr0z6/files/best_model.pth
# ✅ New best model saved with F1: 0.6220
#
# ============================================================
# Epoch 8/30
# ============================================================
# Epoch 8 Training: 100%|██████████| 592/592 [04:27<00:00,  2.21it/s, Loss=0.9802, Acc=73.23%, LR=8.73e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.2022, Acc=65.87%]
# 📊 Epoch 8 Summary:
# Train - Loss: 0.9802, Acc: 73.23%, F1: 0.7259
# Val   - Loss: 1.2022, Acc: 65.87%, F1: 0.6489
# Learning Rate: 8.36e-05
#   Time - Epoch: 296.9s, Inference: 12.5ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260223_081229-mgonr0z6/files/best_model.pth
# ✅ New best model saved with F1: 0.6489
#
# ============================================================
# Epoch 9/30
# ============================================================
# Epoch 9 Training: 100%|██████████| 592/592 [04:27<00:00,  2.22it/s, Loss=0.9670, Acc=73.56%, LR=8.36e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.2510, Acc=63.00%]
# 📊 Epoch 9 Summary:
# Train - Loss: 0.9670, Acc: 73.56%, F1: 0.7309
# Val   - Loss: 1.2510, Acc: 63.00%, F1: 0.6237
# Learning Rate: 7.96e-05
#   Time - Epoch: 296.7s, Inference: 12.0ms
#
# ============================================================
# Epoch 10/30
# ============================================================
# Epoch 10 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.9451, Acc=74.70%, LR=7.96e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.2086, Acc=67.46%]
# 📊 Epoch 10 Summary:
# Train - Loss: 0.9451, Acc: 74.70%, F1: 0.7421
# Val   - Loss: 1.2086, Acc: 67.46%, F1: 0.6614
# Learning Rate: 7.52e-05
#   Time - Epoch: 295.9s, Inference: 11.1ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260223_081229-mgonr0z6/files/best_model.pth
# ✅ New best model saved with F1: 0.6614
#
# ============================================================
# Epoch 11/30
# ============================================================
# Epoch 11 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.9422, Acc=75.13%, LR=7.52e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.2046, Acc=66.99%]
# 📊 Epoch 11 Summary:
# Train - Loss: 0.9422, Acc: 75.13%, F1: 0.7468
# Val   - Loss: 1.2046, Acc: 66.99%, F1: 0.6556
# Learning Rate: 7.06e-05
#   Time - Epoch: 296.0s, Inference: 12.4ms
#
# ============================================================
# Epoch 12/30
# ============================================================
# Epoch 12 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.9200, Acc=75.86%, LR=7.06e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.36it/s, Loss=1.1946, Acc=67.46%]
# 📊 Epoch 12 Summary:
# Train - Loss: 0.9200, Acc: 75.86%, F1: 0.7544
# Val   - Loss: 1.1946, Acc: 67.46%, F1: 0.6630
# Learning Rate: 6.58e-05
#   Time - Epoch: 295.9s, Inference: 11.3ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260223_081229-mgonr0z6/files/best_model.pth
# ✅ New best model saved with F1: 0.6630
#
# ============================================================
# Epoch 13/30
# ============================================================
# Epoch 13 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.9103, Acc=76.43%, LR=6.58e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.2308, Acc=66.03%]
# 📊 Epoch 13 Summary:
# Train - Loss: 0.9103, Acc: 76.43%, F1: 0.7606
# Val   - Loss: 1.2308, Acc: 66.03%, F1: 0.6511
# Learning Rate: 6.08e-05
#   Time - Epoch: 295.9s, Inference: 12.2ms
#
# ============================================================
# Epoch 14/30
# ============================================================
# Epoch 14 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.8972, Acc=76.92%, LR=6.08e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.2482, Acc=66.83%]
# 📊 Epoch 14 Summary:
# Train - Loss: 0.8972, Acc: 76.92%, F1: 0.7669
# Val   - Loss: 1.2482, Acc: 66.83%, F1: 0.6467
# Learning Rate: 5.57e-05
#   Time - Epoch: 295.8s, Inference: 11.4ms
#
# ============================================================
# Epoch 15/30
# ============================================================
# Epoch 15 Training: 100%|██████████| 592/592 [04:26<00:00,  2.22it/s, Loss=0.8906, Acc=77.40%, LR=5.57e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.2241, Acc=66.19%]
# 📊 Epoch 15 Summary:
# Train - Loss: 0.8906, Acc: 77.40%, F1: 0.7708
# Val   - Loss: 1.2241, Acc: 66.19%, F1: 0.6464
# Learning Rate: 5.05e-05
#   Time - Epoch: 295.9s, Inference: 11.3ms
#
# ============================================================
# Epoch 16/30
# ============================================================
# Epoch 16 Training: 100%|██████████| 592/592 [04:27<00:00,  2.21it/s, Loss=0.8747, Acc=78.15%, LR=5.05e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.2387, Acc=66.99%]
# 📊 Epoch 16 Summary:
# Train - Loss: 0.8747, Acc: 78.15%, F1: 0.7790
# Val   - Loss: 1.2387, Acc: 66.99%, F1: 0.6546
# Learning Rate: 4.53e-05
#   Time - Epoch: 297.3s, Inference: 10.4ms
#
# ============================================================
# Epoch 17/30
# ============================================================
# Epoch 17 Training: 100%|██████████| 592/592 [04:27<00:00,  2.21it/s, Loss=0.8700, Acc=78.44%, LR=4.53e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.2424, Acc=68.58%]
# 📊 Epoch 17 Summary:
# Train - Loss: 0.8700, Acc: 78.44%, F1: 0.7810
# Val   - Loss: 1.2424, Acc: 68.58%, F1: 0.6690
# Learning Rate: 4.02e-05
#   Time - Epoch: 297.3s, Inference: 11.7ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260223_081229-mgonr0z6/files/best_model.pth
# ✅ New best model saved with F1: 0.6690
#
# ============================================================
# Epoch 18/30
# ============================================================
# Epoch 18 Training: 100%|██████████| 592/592 [04:27<00:00,  2.21it/s, Loss=0.8567, Acc=78.89%, LR=4.02e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.2483, Acc=66.83%]
# 📊 Epoch 18 Summary:
# Train - Loss: 0.8567, Acc: 78.89%, F1: 0.7859
# Val   - Loss: 1.2483, Acc: 66.83%, F1: 0.6612
# Learning Rate: 3.52e-05
#   Time - Epoch: 297.3s, Inference: 10.8ms
#
# ============================================================
# Epoch 19/30
# ============================================================
# Epoch 19 Training: 100%|██████████| 592/592 [04:27<00:00,  2.21it/s, Loss=0.8514, Acc=79.03%, LR=3.52e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.2143, Acc=66.67%]
# 📊 Epoch 19 Summary:
# Train - Loss: 0.8514, Acc: 79.03%, F1: 0.7880
# Val   - Loss: 1.2143, Acc: 66.67%, F1: 0.6555
# Learning Rate: 3.04e-05
#   Time - Epoch: 297.4s, Inference: 11.9ms
#
# ============================================================
# Epoch 20/30
# ============================================================
# Epoch 20 Training: 100%|██████████| 592/592 [04:27<00:00,  2.21it/s, Loss=0.8490, Acc=79.05%, LR=3.04e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.2250, Acc=68.10%]
# 📊 Epoch 20 Summary:
# Train - Loss: 0.8490, Acc: 79.05%, F1: 0.7885
# Val   - Loss: 1.2250, Acc: 68.10%, F1: 0.6697
# Learning Rate: 2.58e-05
#   Time - Epoch: 297.4s, Inference: 9.8ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260223_081229-mgonr0z6/files/best_model.pth
# ✅ New best model saved with F1: 0.6697
#
# ============================================================
# Epoch 21/30
# ============================================================
# Epoch 21 Training: 100%|██████████| 592/592 [04:27<00:00,  2.21it/s, Loss=0.8431, Acc=79.89%, LR=2.58e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.2440, Acc=66.99%]
# 📊 Epoch 21 Summary:
# Train - Loss: 0.8431, Acc: 79.89%, F1: 0.7960
# Val   - Loss: 1.2440, Acc: 66.99%, F1: 0.6603
# Learning Rate: 2.14e-05
#   Time - Epoch: 297.5s, Inference: 10.4ms
#
# ============================================================
# Epoch 22/30
# ============================================================
# Epoch 22 Training: 100%|██████████| 592/592 [04:27<00:00,  2.21it/s, Loss=0.8313, Acc=80.14%, LR=2.14e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.2544, Acc=67.15%]
# 📊 Epoch 22 Summary:
# Train - Loss: 0.8313, Acc: 80.14%, F1: 0.7993
# Val   - Loss: 1.2544, Acc: 67.15%, F1: 0.6669
# Learning Rate: 1.74e-05
#   Time - Epoch: 297.3s, Inference: 10.1ms
#
# ============================================================
# Epoch 23/30
# ============================================================
# Epoch 23 Training: 100%|██████████| 592/592 [04:27<00:00,  2.21it/s, Loss=0.8227, Acc=81.15%, LR=1.74e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.2423, Acc=68.10%]
# 📊 Epoch 23 Summary:
# Train - Loss: 0.8227, Acc: 81.15%, F1: 0.8091
# Val   - Loss: 1.2423, Acc: 68.10%, F1: 0.6748
# Learning Rate: 1.37e-05
#   Time - Epoch: 297.4s, Inference: 10.5ms
# Model saved to /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260223_081229-mgonr0z6/files/best_model.pth
# ✅ New best model saved with F1: 0.6748
#
# ============================================================
# Epoch 24/30
# ============================================================
# Epoch 24 Training: 100%|██████████| 592/592 [04:27<00:00,  2.21it/s, Loss=0.8250, Acc=80.61%, LR=1.37e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.2532, Acc=66.67%]
# 📊 Epoch 24 Summary:
# Train - Loss: 0.8250, Acc: 80.61%, F1: 0.8038
# Val   - Loss: 1.2532, Acc: 66.67%, F1: 0.6620
# Learning Rate: 1.05e-05
#   Time - Epoch: 297.2s, Inference: 10.2ms
#
# ============================================================
# Epoch 25/30
# ============================================================
# Epoch 25 Training: 100%|██████████| 592/592 [04:27<00:00,  2.21it/s, Loss=0.8243, Acc=81.05%, LR=1.05e-05]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.2408, Acc=67.62%]
# 📊 Epoch 25 Summary:
# Train - Loss: 0.8243, Acc: 81.05%, F1: 0.8088
# Val   - Loss: 1.2408, Acc: 67.62%, F1: 0.6707
# Learning Rate: 7.63e-06
#   Time - Epoch: 297.3s, Inference: 10.3ms
#
# ============================================================
# Epoch 26/30
# ============================================================
# Epoch 26 Training: 100%|██████████| 592/592 [04:27<00:00,  2.21it/s, Loss=0.8207, Acc=81.09%, LR=7.63e-06]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.2593, Acc=66.83%]
# 📊 Epoch 26 Summary:
# Train - Loss: 0.8207, Acc: 81.09%, F1: 0.8082
# Val   - Loss: 1.2593, Acc: 66.83%, F1: 0.6636
# Learning Rate: 5.28e-06
#   Time - Epoch: 297.4s, Inference: 11.0ms
#
# ============================================================
# Epoch 27/30
# ============================================================
# Epoch 27 Training: 100%|██████████| 592/592 [04:27<00:00,  2.21it/s, Loss=0.8128, Acc=81.06%, LR=5.28e-06]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.2626, Acc=67.78%]
# 📊 Epoch 27 Summary:
# Train - Loss: 0.8128, Acc: 81.06%, F1: 0.8092
# Val   - Loss: 1.2626, Acc: 67.78%, F1: 0.6715
# Learning Rate: 3.42e-06
#   Time - Epoch: 297.3s, Inference: 10.6ms
#
# ============================================================
# Epoch 28/30
# ============================================================
# Epoch 28 Training: 100%|██████████| 592/592 [04:27<00:00,  2.21it/s, Loss=0.8221, Acc=80.25%, LR=3.42e-06]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.2624, Acc=67.30%]
# 📊 Epoch 28 Summary:
# Train - Loss: 0.8221, Acc: 80.25%, F1: 0.8008
# Val   - Loss: 1.2624, Acc: 67.30%, F1: 0.6671
# Learning Rate: 2.08e-06
#   Time - Epoch: 297.5s, Inference: 11.1ms
#
# ============================================================
# Epoch 29/30
# ============================================================
# Epoch 29 Training: 100%|██████████| 592/592 [04:27<00:00,  2.21it/s, Loss=0.8088, Acc=81.30%, LR=2.08e-06]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.2618, Acc=67.46%]
# 📊 Epoch 29 Summary:
# Train - Loss: 0.8088, Acc: 81.30%, F1: 0.8114
# Val   - Loss: 1.2618, Acc: 67.46%, F1: 0.6696
# Learning Rate: 1.27e-06
#   Time - Epoch: 297.5s, Inference: 11.0ms
#
# ============================================================
# Epoch 30/30
# ============================================================
# Epoch 30 Training: 100%|██████████| 592/592 [04:27<00:00,  2.21it/s, Loss=0.8090, Acc=81.42%, LR=1.27e-06]
# Validation: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.2613, Acc=66.99%]
# 📊 Epoch 30 Summary:
# Train - Loss: 0.8090, Acc: 81.42%, F1: 0.8123
# Val   - Loss: 1.2613, Acc: 66.99%, F1: 0.6647
# Learning Rate: 1.00e-06
#   Time - Epoch: 297.6s, Inference: 11.8ms
#
# 🎉 Training completed!
# 📈 Best validation F1: 0.6748
# ⏱️  Average epoch time: 297.1s
# ⚡ Average inference time: 11.5ms

# %%
# cell 6: Test
test_loss, test_acc, test_f1 = trainer.test()
print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}, Test F1: {test_f1:.4f}")
# Out:
# ============================================================
# Testing Model
# ============================================================
# Model loaded from /home/ray/Projects/ITI123-GenerativeAIDeepLearningProject/wandb/run-20260223_081229-mgonr0z6/files/best_model.pth
# Testing: 100%|██████████| 40/40 [00:29<00:00,  1.35it/s, Loss=1.2333, Acc=65.23%]
# 📊 Test Results:
# Test Loss: 1.2333
# Test Accuracy: 65.23%
# Test Weighted F1 Score: 0.6475
# Average Inference Time per Image: 9.71 ms
#
# 📋 Detailed Classification Report:
#               precision    recall  f1-score   support
#
#       normal       0.70      0.72      0.71       282
#     diabetes       0.59      0.62      0.60       160
#     glaucoma       0.72      0.46      0.57        28
#     cataract       0.65      0.89      0.75        27
#       ageing       0.81      0.65      0.72        26
# hypertension       0.25      0.15      0.19        13
#       myopia       0.81      0.91      0.86        23
#        other       0.51      0.44      0.47        68
#
#     accuracy                           0.65       627
#    macro avg       0.63      0.61      0.61       627
# weighted avg       0.65      0.65      0.65       627
#
# Test Loss: 1.2333, Test Acc: 65.2313, Test F1: 0.6475

# %%
import os
final_model_path = os.path.join('ODIR-2019/results/', saved_model_name)
trainer.save_model(final_model_path)
# Out:
# Model saved to ODIR-2019/results/efficientnet-b4-odir-2019-pmu.pth

# %%
wandb.finish()
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>learning_rate</td><td>█████▇▇▇▇▆▆▆▅▅▅▄▄▃▃▃▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>test_acc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>train_acc</td><td>▁▃▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇█████████</td></tr><tr><td>train_f1</td><td>▁▃▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇██████████</td></tr><tr><td>train_loss</td><td>█▆▅▅▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▄▅▅▅▆▆▇▅▇▇▇▇▇▇▇█▇▇█▇▇█▇█▇█▇▇▇</td></tr><tr><td>val_f1</td><td>▁▄▅▅▆▆▆▇▆█▇█▇▇▇▇██▇█▇█████████</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>30</td></tr><tr><td>learning_rate</td><td>0.0</td></tr><tr><td>test_acc</td><td>65.23126</td></tr><tr><td>test_f1</td><td>0.64753</td></tr><tr><td>test_loss</td><td>1.23328</td></tr><tr><td>train_acc</td><td>81.41892</td></tr><tr><td>train_f1</td><td>0.81231</td></tr><tr><td>train_loss</td><td>0.80901</td></tr><tr><td>val_acc</td><td>66.98565</td></tr><tr><td>val_f1</td><td>0.66474</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">efficientnet-b4_pmu</strong> at: <a href='https://wandb.ai/samalo/odir-2019/runs/mgonr0z6' target="_blank">https://wandb.ai/samalo/odir-2019/runs/mgonr0z6</a><br> View project at: <a href='https://wandb.ai/samalo/odir-2019' target="_blank">https://wandb.ai/samalo/odir-2019</a><br>Synced 5 W&B file(s), 9 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260223_081229-mgonr0z6/logs</code>
